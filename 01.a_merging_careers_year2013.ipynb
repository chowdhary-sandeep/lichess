# %%
import time
import pandas as pd
import glob
import numpy as np
import timeit
import pickle

from multiprocessing import Pool
from matplotlib import pyplot as plt
def toc(start_time):
    elapsed = timeit.default_timer() - start_time
    print(elapsed)
start_time = timeit.default_timer()

# import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})
#matplotlib.rcParams.update({'font.size': 18})

path_dicts='/mnt/sdb1/sandeep/dicts_chess/'

# %%
YEAR_OF_PGN=2013
MONTH_OF_PGN=1
if MONTH_OF_PGN<10: MONTH_OF_PGN='0'+str(MONTH_OF_PGN)
    
t_ic=time.time()
file_to_read = open(path_dicts+"dict_lichess_db_standard_rated_"+str(YEAR_OF_PGN)+"-"+str(MONTH_OF_PGN)+".pkl", "rb")
dict_career_MAIN = pickle.load(file_to_read)


t_oc=time.time()
print(t_oc-t_ic)
# Out:
# 0.32712435722351074

# %%
t_ic=time.time()

for MONTH_OF_PGN in range(2,13):
    if MONTH_OF_PGN<10: MONTH_OF_PGN='0'+str(MONTH_OF_PGN)

    file_to_read = open(path_dicts+"dict_lichess_db_standard_rated_"+str(YEAR_OF_PGN)+"-"+str(MONTH_OF_PGN)+".pkl", "rb")
    dict_career= pickle.load(file_to_read)


    it_career=0
    LL=len(dict_career.keys())
    for key_ in dict_career.keys():
        it_career=it_career+1
        career_=dict_career[key_]

        if key_ in dict_career_MAIN.keys():
            dict_career_MAIN[key_]=dict_career_MAIN[key_]+career_
        else:
            dict_career_MAIN[key_]=career_
#             dict_career_MAIN.setdefault(key_, []).append(career_)


        if it_career % 5000 == 0:
            t_oc = time.time();
            print('MONTH=',MONTH_OF_PGN,'-----',it_career/LL)
            with open("/mnt/sdb1/sandeep/0. Careers in chess/b_PROG_MERGING_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
                file_object.write('Y='+str(YEAR_OF_PGN)+'-MONTH='+str(MONTH_OF_PGN)+'--'+str(it_career/LL)+'--i.e.-'+str(it_career)+'/'+str(LL)+'----time (s)-'+str(round(t_oc-t_ic,2))+'\n')

# print(t_oc-t_ic)
#----------------------------------------------------
# Writing dictionary to file 
#----------------------------------------------------       
with open("/mnt/sdb1/sandeep/0. Careers in chess/b_PROG_MERGING_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
    file_object.write('writing dict to file ------------\n')

file_write=path_dicts+"dict_merged_"+str(YEAR_OF_PGN)+".pkl"
with open(file_write, 'wb') as f:
    pickle.dump(dict_career_MAIN, f, pickle.HIGHEST_PROTOCOL)
with open("/mnt/sdb1/sandeep/0. Careers in chess/b_PROG_MERGING_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
    file_object.write('done writing dict to file ------------\n')

t_oc=time.time();
print(t_oc-t_ic,' seconds')
# Out:
# MONTH= 03 ----- 0.8404773911581779
# MONTH= 04 ----- 0.7797878976918278
# MONTH= 05 ----- 0.668985817500669
# MONTH= 06 ----- 0.5268703898840885
# MONTH= 07 ----- 0.4348582362149939
# MONTH= 07 ----- 0.8697164724299878
# MONTH= 08 ----- 0.41893590280687054
# MONTH= 08 ----- 0.8378718056137411
# MONTH= 09 ----- 0.3850893407270487
# MONTH= 09 ----- 0.7701786814540974
# MONTH= 10 ----- 0.3788165770134101
# MONTH= 10 ----- 0.7576331540268202
# MONTH= 11 ----- 0.3126367785906334
# MONTH= 11 ----- 0.6252735571812668
# MONTH= 11 ----- 0.9379103357719002
# MONTH= 12 ----- 0.25220680958385877
# MONTH= 12 ----- 0.5044136191677175
# MONTH= 12 ----- 0.7566204287515763
# 50.15230584144592  seconds

# %% [markdown]
# ## Checking if careers are stored correctly as lists at this step

# %%
cc=0
store_issues=[]
for key_ in dict_career:
    cc=cc+1; 
    career_=dict_career[key_]
    issues_=([int(isinstance(elem[0], list)) for elem in career_])
    store_issues.append(sum(issues_))

    if cc>0: 
        break;
#

# %%
career_
# Out:
# [['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'danilober',
#   '0-1',
#   '2013.11.30',
#   '23:00:16',
#   '1253',
#   '1586',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 Nxe4 4. Bxf7+ Kxf7 5. Nxe5+ Kg8 6. O-O d6 7. Nc4 b5 8. Ne3 Bb7 9. d3 Nf6 10. c3 g6 11. f4 Bg7 12. f5 Nc6 13. Qb3+ Kf8 14. fxg6 hxg6 15. Ng4 Ne5 16. Nxf6 Bxf6 17. d4 Ng4 18. Bg5 Kg7 19. Bxf6+ Nxf6 20. Qe6 Rhe8 21. Qh3 Re2 22. Na3 Rxg2+ 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'vondepaul',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.11.30',
#   '23:07:28',
#   '1436',
#   '1533',
#   'Center Game: Normal Variation',
#   '1. e4 e5 2. d4 exd4 3. Qxd4 Nc6 4. Qd1 Bc5 5. Bd3 Bxf2+ 6. Kxf2 Qf6+ 7. Nf3 Ne5 8. Bg5 Ng4+ 9. Kg1 Qb6+ 10. Kf1 Qf2# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'toba_nomade',
#   '1-0',
#   '2013.12.01',
#   '16:37:49',
#   '1542',
#   '1449',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 a6 4. Bxf7+ Kxf7 5. Nxe5+ Ke8 6. O-O d6 7. Nc4 Be7 8. e5 dxe5 9. Nxe5 Qd6 10. f4 Qc5+ 11. d4 Qd6 12. f5 Nc6 13. Bg5 Nxe5 14. Bxf6 Bxf6 15. Qh5+ Ke7 16. dxe5 Qd4+ 17. Kh1 Qxe5 18. Nc3 Bd7 19. Rae1 Be8 20. Qd1 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'kasra',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '17:52:40',
#   '1558',
#   '1247',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Nxe5 Bc5 5. Bc4 d5 6. Bb3 O-O 7. O-O Bxf5 8. Nc3 Kh8 9. d4 Bd6 10. Bg5 Qe8 11. Rfe1 Bg4 12. Nxg4 Nxg4 13. Rxe8 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'kasra',
#   '1-0',
#   '2013.12.01',
#   '17:55:19',
#   '1241',
#   '1561',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 Nxe4 4. Bxf7+ Kxf7 5. Nxe5+ Ke7 6. O-O d6 7. Nc4 Be6 8. Rfe1 d5 9. Ne5 Nc6 10. d3 Nxe5 11. dxe4 dxe4 12. Bg5+ Ke8 13. Bxd8 Raxd8 14. Qh5+ Ng6 15. Nc3 Rd4 16. f4 Bf7 17. Qb5+ c6 18. Qxb7 Be7 19. Qxc6+ Kf8 20. Qc8+ Rdd8 21. Qb7 Be8 22. Qxe4 Rd6 23. f5 Bc6 24. Qe2 Kf7 25. fxg6+ hxg6 26. Qxe7+ Kg8 27. Qxd6 Bb7 28. Qc7 Bxg2 29. Kxg2 Kh7 30. Re3 Kh6 31. Rh3+ Kg5 32. Qe5+ Kg4 33. Qg3+ Kf5 34. Rf1+ Ke6 35. Qe3+ Kd6 36. Rxh8 Kc6 37. Rc8+ Kb7 38. Qc5 Ka6 39. Rc6+ Kb7 40. Rf7+ Kb8 41. Qf8# 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'kasra',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '18:05:16',
#   '1543',
#   '1277',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Nxe5 Bc5 5. Bc4 d5 6. Bb3 O-O 7. O-O c6 8. d4 Bd6 9. Rfe1 Bxf5 10. Bg5 Be7 11. Nc3 Ne4 12. Bxe7 Qxe7 13. Nxe4 Bxe4 14. f3 Bf5 15. Nxc6 Qg5 16. Ne7+ Kh8 17. Nxf5 Qxf5 18. Re5 Qg6 19. Bxd5 Nc6 20. Re6 Qh5 21. Bxc6 bxc6 22. Rxc6 Rae8 23. d5 Qe5 24. Re6 Rxe6 25. dxe6 Qxe6 26. Qe1 Qb6+ 27. Kh1 Qxb2 28. Qb1 Qd4 29. Qd1 Qb2 30. h3 Re8 31. Qb1 Qd4 32. Qd1 Qb2 33. Qb1 Qd4 34. Qd1 Qb2 35. a4 a5 36. Rb1 Qa3 37. Qd7 Rf8 38. Qb5 Qa2 39. Rg1 Qxc2 40. Qxa5 h6 41. Qb4 Qc7 42. Qxf8+ Kh7 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'aduin',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.01',
#   '18:17:36',
#   '1720',
#   '1550',
#   'Latvian Gambit: Mlotkowski Variation',
#   '1. Nc3 e5 2. Nf3 f5 3. e4 Nf6 4. Nxe5 Bc5 5. exf5 O-O 6. Bc4+ d5 7. Be2 Nc6 8. Nxc6 bxc6 9. O-O Bxf5 10. d4 Bd6 11. Bg5 Be7 12. Bxf6 Bxf6 13. Bf3 Bh4 14. Ne2 Qg5 15. g3 Bxg3 16. Nxg3 Bh3 17. Bg2 Bg4 18. Bf3 Rxf3 19. Rfe1 Rxg3+ 20. hxg3 Bxd1 21. Raxd1 Rf8 22. Re5 Qf6 23. Rde1 h6 24. Re5e8 Rxe8 25. Rxe8+ Kh7 26. Ra8 Qxd4 27. c3 Qd1+ 28. Kg2 Qc2 29. Rxa7 Qxb2 30. Rxc7 Qxc3 31. a4 d4 32. Ra7 d3 33. a5 d2 34. a6 d1=Q 35. Rb7 c5 36. a7 Qd5+ 37. f3 Qxb7 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'Paupau',
#   '0-1',
#   '2013.12.01',
#   '18:25:40',
#   '1269',
#   '1486',
#   'French Defense #2',
#   '1. e4 e6 2. Bc4 d5 3. exd5 exd5 4. Bd3 Nc6 5. c4 d4 6. c5 Bxc5 7. Bc4 Nf6 8. Bxf7+ Kxf7 9. Nf3 Rhe8+ 10. Kf1 Bg4 11. Ng5+ Kg8 12. Qb3+ Qd5 13. Qg3 Qxg5 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'dusica',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '18:28:15',
#   '1820',
#   '1260',
#   "Bishop's Opening: Boi Variation",
#   '1. e4 e5 2. Bc4 Bc5 3. Nc3 f5 4. exf5 Nf6 5. Nf3 d5 6. Bb3 O-O 7. O-O e4 8. Nh4 Kh8 9. d4 exd3 10. Qxd3 c6 11. Bg5 Qd6 12. Rae1 Ng4 13. g3 Ne5 14. Qd1 Nbd7 15. Qh5 Nf6 16. Bxf6 Rxf6 17. Qe8+ Rff8 18. Qxe5 Qh6 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'lin',
#   '1-0',
#   '2013.12.01',
#   '18:56:05',
#   '1565',
#   '1120',
#   'Owen Defense',
#   '1. e4 b6 2. Bc4 Bb7 3. d3 f5 4. Qh5+ g6 5. exf5 Bxg2 6. fxg6 d5 7. g7+ Kd7 8. gxh8=Q Nf6 9. Bb5+ Nc6 10. Bxc6+ Kxc6 11. Qe2 Bxh1 12. Bg5 Qd6 13. Bxf6 exf6 14. Qxh7 Be7 15. Qexe7 Qxe7+ 16. Qxe7 d4 17. f3 Rg8 18. Qe4+ Kb5 19. Na3+ Ka6 20. Qxd4 Rxg1+ 21. Qxg1 Bxf3 22. c4 c5 23. Nb5 Kb7 24. Nd6+ Kc6 25. Ne8 f5 26. Qg6+ Kd7 27. Nf6+ Ke6 28. Ng4+ Kd7 29. Qxf5+ 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'theoldiniquity',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '19:06:13',
#   '1521',
#   '1567',
#   'Latvian Gambit',
#   '1. e4 e5 2. Nf3 f5 3. Nxe5 Nf6 4. Nc3 Bc5 5. exf5 d6 6. Nd3 Bb6 7. Be2 O-O 8. O-O Bxf5 9. Nf4 d5 10. d3 d4 11. Nb5 a6 12. Na3 c5 13. Nc4 Bc7 14. c3 b5 15. Na3 Nc6 16. cxd4 Nxd4 17. Nc2 Nxe2+ 18. Qxe2 Bg4 19. f3 Rfe8 20. Qf2 Bb6 21. fxg4 c4 22. Be3 Nxg4 23. Bxb6 Nxf2 24. Bxd8 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'theoldiniquity',
#   '1-0',
#   '2013.12.01',
#   '19:21:57',
#   '1554',
#   '1533',
#   'French Defense #2',
#   '1. e4 e6 2. Bc4 d5 3. exd5 exd5 4. Bd3 Nf6 5. Ne2 Be7 6. O-O O-O 7. f4 Bg4 8. Qe1 Rfe8 9. Qg3 Bh5 10. Nd4 Bc5 11. c3 Nc6 12. Kh1 Nxd4 13. cxd4 Bxd4 14. Nc3 c6 15. Bc2 h6 16. d3 Qc7 17. Bd1 Bg6 18. Qh3 Bxd3 19. Qxd3 Re3 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'theoldiniquity',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '19:31:27',
#   '1523',
#   '1565',
#   'Latvian Gambit',
#   '1. e4 { [%eval 0.2] } 1... e5 { [%eval 0.26] } 2. Nf3 { [%eval 0.26] } 2... f5? { [%eval 1.27] } 3. Nxe5 { [%eval 0.84] } 3... Nf6?! { [%eval 1.43] } 4. exf5?! { [%eval 0.72] } 4... d5? { [%eval 1.89] } 5. d4 { [%eval 1.81] } 5... Bd6 { [%eval 1.83] } 6. Bd3 { [%eval 1.75] } 6... O-O { [%eval 1.73] } 7. O-O { [%eval 1.79] } 7... c5 { [%eval 1.73] } 8. c3 { [%eval 1.73] } 8... c4? { [%eval 2.84] } 9. Bc2 { [%eval 2.84] } 9... Ne4 { [%eval 2.92] } 10. Nd2?! { [%eval 2.32] } 10... Bxf5 { [%eval 2.62] } 11. Nxe4 { [%eval 2.5] } 11... Bxe4? { [%eval 3.55] } 12. Bxe4 { [%eval 3.53] } 12... dxe4 { [%eval 3.71] } 13. Rfe1? { [%eval 1.01] } 13... Qh4? { [%eval 3.33] } 14. g3 { [%eval 2.98] } 14... Qf6 { [%eval 3.01] } 15. Bf4 { [%eval 2.76] } 15... Na6? { [%eval 3.79] } 16. Rxe4 { [%eval 3.73] } 16... Rad8? { [%eval 4.88] } 17. Qd2? { [%eval 3.13] } 17... h6? { [%eval 4.78] } 18. Nxc4 { [%eval 4.66] } 18... Bxf4 { [%eval 4.88] } 19. Rxf4 { [%eval 4.88] } 19... Qe7 { [%eval 5.33] } 20. Re1 { [%eval 5.57] } 20... Qc7 { [%eval 5.45] } 21. Rxf8+ { [%eval 5.57] } 21... Rxf8 { [%eval 5.57] } 22. Ne5 { [%eval 5.55] } 22... Qd6 { [%eval 5.55] } 23. Qe2 { [%eval 5.33] } 23... Nc7 { [%eval 5.33] } 24. Qg4 { [%eval 5.25] } 24... Rf6? { [%eval 6.72] } 25. Re4? { [%eval 5.01] } 25... a6? { [%eval 6.78] } 26. Rf4? { [%eval 5.63] } 26... Rxf4 { [%eval 5.61] } 27. Qxf4 { [%eval 5.71] } 27... Ne6? { [%eval 7.37] } 28. Qf7+ { [%eval 7.43] } 28... Kh7 { [%eval 7.43] } 29. Qg6+ { [%eval 7.47] } 29... Kg8 { [%eval 7.37] } 30. Qf7+?? { [%eval 0.0] } 30... Kh7 { [%eval 7.61] } 31. Qxb7 { [%eval 7.61] } 31... Ng5? { [%eval 10.36] } 32. Nf7?? { [%eval 6.12] } 32... Qf6?! { [%eval 6.78] } 33. Nxg5+ { [%eval 7.15] } 33... hxg5 { [%eval 7.15] } 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'Den-Den-2013',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '19:50:22',
#   '1612',
#   '1258',
#   "King's Gambit Declined: Keene's Defense #2",
#   '1. e4 e5 2. f4 Qh4+ 3. g3 Qd8 4. fxe5 Bc5 5. d4 Bb6 6. Nf3 Ne7 7. Bh3 d5 8. Bxc8 Qxc8 9. exd5 O-O 10. c4 Qh3 11. Qe2 Nf5 12. Qf2 Nxd4 13. Nxd4 Bxd4 14. Qxd4 Qg2 15. Rhg1 Qxh2 16. Nc3 c5 17. Qe3 Na6 18. a3 b5 19. Nxb5 f5 20. Bd2 f4 21. gxf4 Rxf4 22. O-O-O Rxc4+ 23. Bc3 Rb8 24. e6 Rxb5 25. Rxg7+ Kf8 26. Rf1+ Ke8 27. Rg8+ Ke7 28. Rf7+ Kd6 29. Rd7# 1-0\n'],
#  ['Rated Blitz game',
#   'Time forfeit',
#   'ASTROSCEPTRE',
#   'pipolon-1966',
#   '0-1',
#   '2013.12.01',
#   '19:59:07',
#   '1254',
#   '1713',
#   'Pirc Defense #4',
#   '1. e4 d6 2. Bc4 e6 3. Nf3 Nc6 4. d4 g6 5. Ng5 Bg7 6. Nxf7 Kxf7 7. Qf3+ Qf6 8. Qb3 Na5 9. Qa4 Nxc4 10. Qxc4 Ne7 11. O-O Rhf8 12. e5 dxe5 13. f4 e4 14. Qxc7 Kg8 15. Nc3 Qxd4+ 16. Kh1 Nf5 17. Nb5 Qb6 18. Qc4 e3 19. Rfe1 a6 20. Nc3 Bd7 21. Bxe3 Qc6 22. Qe2 Rae8 23. Rad1 b5 24. Rxd7 Qxd7 25. Rd1 Qb7 26. Kg1 e5 27. g4 Nh4 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'apl',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '20:17:53',
#   '1751',
#   '1552',
#   'Latvian Gambit Accepted',
#   '1. e4 { [%eval 0.24] } 1... e5 { [%eval 0.3] } 2. Nf3 { [%eval 0.3] } 2... f5?! { [%eval 1.01] } 3. exf5 { [%eval 1.09] } 3... Nf6 { [%eval 0.98] } 4. Nxe5 { [%eval 0.68] } 4... Bc5? { [%eval 2.16] } 5. Bc4? { [%eval 1.15] } 5... d5 { [%eval 1.13] } 6. Be2 { [%eval 1.15] } 6... O-O { [%eval 1.15] } 7. d4 { [%eval 1.19] } 7... Bd6 { [%eval 1.19] } 8. Nc3 { [%eval 1.31] } 8... Bxf5 { [%eval 1.27] } 9. Bg5 { [%eval 1.07] } 9... Qd7?? { [%eval 10.0] } 10. Nxd7 { [%eval 10.1] } 1-0\n'],
#  ['Rated Bullet game',
#   'Time forfeit',
#   'massmedia56',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '20:22:21',
#   '1375',
#   '1102',
#   "Bishop's Opening: Calabrese Countergambit",
#   '1. e4 e5 2. Bc4 f5 3. Qf3 Nf6 4. d4 fxe4 5. Qf5 d5 6. Bb5+ c6 7. Qxe5+ Be7 8. Be2 O-O 9. Qg3 Bd6 10. f4 Rfe8 11. Qg5 e3 12. Bh5 Re7 13. f5 Qa5+ 14. c3 b5 15. Bg6 b4 16. Bxh7+ Nxh7 17. f6 bxc3 18. fxg7 Rxg7 19. Qh6 cxb2+ 20. Nd2 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'S0HAIB',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '20:26:39',
#   '1361',
#   '1251',
#   'Dutch Defense',
#   '1. d4 f5 2. f3 Nf6 3. Nc3 d5 4. e3 e6 5. b3 Bd6 6. Bd3 O-O 7. Bb2 c5 8. dxc5 Bxc5 9. Qd2 e5 10. O-O-O Bb4 11. Nh3 d4 12. exd4 exd4 13. a3 Ba5 14. b4 Bb6 15. Na4 a5 16. Nxb6 Qxb6 17. Bc4+ Kh8 18. Bxd4 Qd8 19. b5 Qe7 20. Bb2 Be6 21. Rhe1 Rfd8 22. Qc3 Nd5 23. Bxd5 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'S0HAIB',
#   '1-0',
#   '2013.12.01',
#   '20:34:49',
#   '1237',
#   '1369',
#   'Italian Game',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 f6 4. O-O Bc5 5. a3 b6 6. b4 Bd6 7. d4 Bb7 8. d5 Nce7 9. Nh4 c6 10. Qh5+ g6 11. Qd1 cxd5 12. Bxd5 Bxd5 13. exd5 Qc8 14. c4 Qxc4 15. f4 Nxd5 16. fxe5 Bxe5 17. Nf3 Bxa1 18. Re1+ Nge7 19. Kh1 O-O 20. Bh6 Rfe8 21. Nbd2 Qf4 22. Bxf4 Nxf4 23. Qxa1 f5 24. Ng5 d6 25. Qf6 Ref8 26. Qxe7 Rae8 27. Qxh7# 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'S0HAIB',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '20:42:10',
#   '1354',
#   '1263',
#   'Dutch Defense',
#   '1. d4 f5 2. f3 Nf6 3. Nc3 d5 4. f4 e6 5. e3 Bb4 6. g3 O-O 7. Bd2 Bxc3 8. Bxc3 Ne4 9. Bb4 a5 10. Bxf8 Qxf8 11. Nf3 c5 12. Ne5 c4 13. c3 b5 14. Bg2 b4 15. Qa4 b3 16. axb3 Qd6 17. bxc4 dxc4 18. Nxc4 Qe7 19. Ne5 Nd7 20. Nc4 Qd8 21. Nd2 Nb6 22. Qc6 Rb8 23. Nxe4 Bb7 24. Qxe6+ Kh8 25. Qxf5 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'S0HAIB',
#   '1-0',
#   '2013.12.01',
#   '20:49:41',
#   '1249',
#   '1362',
#   "Bishop's Opening",
#   '1. e4 { [%eval 0.24] } 1... e5 { [%eval 0.26] } 2. Bc4 { [%eval 0.14] } 2... Nc6 { [%eval 0.14] } 3. Bxf7+? { [%eval -2.72] } 3... Kxf7 { [%eval -2.86] } 4. Nf3 { [%eval -2.82] } 4... Nf6 { [%eval -2.76] } 5. d4 { [%eval -3.07] } 5... d6?! { [%eval -2.44] } 6. Bg5?! { [%eval -3.39] } 6... Be7 { [%eval -3.25] } 7. d5? { [%eval -4.48] } 7... Na5? { [%eval -2.78] } 8. O-O { [%eval -2.78] } 8... Nxe4? { [%eval -0.38] } 9. Bxe7 { [%eval -0.36] } 9... Qxe7 { [%eval -0.38] } 10. b4?! { [%eval -1.37] } 10... Nc4?! { [%eval -0.58] } 11. Ne1?? { [%eval -5.37] } 11... Rhf8?? { [%eval -1.91] } 12. f3?? { [%eval -5.51] } 12... Ng5? { [%eval -4.42] } 13. f4? { [%eval -6.26] } 13... exf4 { [%eval -6.26] } 14. Qh5+?? { [%eval -10.24] } 14... g6 { [%eval -9.65] } 15. Rxf4+ { [%eval -14.88] } 15... Kg8 { [%eval -10.38] } 16. Rxf8+ { [%eval -10.32] } 16... Qxf8?? { [%eval -2.16] } 17. Qxg5 { [%eval -2.06] } 17... Ne3?? { [%eval 3.97] } 18. Qxe3 { [%eval 4.0] } 18... Bf5 { [%eval 4.24] } 19. Nc3 { [%eval 4.16] } 19... Re8 { [%eval 4.24] } 20. Qd2 { [%eval 4.14] } 20... a6 { [%eval 4.42] } 21. Nf3 { [%eval 4.6] } 21... b6 { [%eval 4.76] } 22. Rf1 { [%eval 4.9] } 22... Re7 { [%eval 5.27] } 23. Ng5?! { [%eval 4.7] } 23... Qf6?? { [%eval 9.15] } 24. g4 { [%eval 9.25] } 24... Qxg5?! { [%eval 24.98] } 25. Qxg5 { [%eval 26.46] } 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'jovitor',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '21:04:25',
#   '1802',
#   '1547',
#   "Dutch Defense: Queen's Knight Variation",
#   '1. d4 f5 2. c4 Nf6 3. Nc3 e6 4. Bg5 Bb4 5. e3 O-O 6. Nf3 Bxc3+ 7. bxc3 Qe8 8. Bxf6 Rxf6 9. Bd3 Rff8 10. O-O b6 11. Rab1 Bb7 12. c5 f4 13. cxb6 cxb6 14. e4 Qh5 15. c4 d6 16. Qb3 Nd7 17. c5 dxc5 18. Qxe6+ Qf7 19. Qxf7+ Rxf7 20. Bc4 Bxe4 21. Bxf7+ Kxf7 22. Rbe1 Bxf3 23. gxf3 Nf6 24. dxc5 bxc5 25. Re5 c4 26. Rc5 Rb8 27. Rxc4 Nd5 28. Rd1 Ke6 29. Re4+ Kd6 30. Red4 Rb5 31. Rxf4 Kc6 32. Rf7 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'mohamad7788',
#   '1-0',
#   '2013.12.01',
#   '21:17:03',
#   '1542',
#   '1214',
#   'Pirc Defense #4',
#   '1. e4 d6 2. Bc4 b6 3. Nf3 Bb7 4. Bxf7+ Kxf7 5. Ng5+ Ke8 6. Qh5+ g6 7. Qf3 Nf6 8. O-O Bh6 9. Ne6 Qd7 10. Qb3 Nxe4 11. d3 Nc5 12. Qc4 Nxe6 13. Bxh6 Ba6 14. Qc3 Nf4 15. Qxh8+ Kf7 16. Qg7+ Ke6 17. Rfe1+ Kf5 18. Qf7+ Kg4 19. h3+ Nxh3+ 20. gxh3+ Kxh3 21. Re3+ Kg4 22. Rg3+ Kh5 23. Qxh7 e5 24. Bf4+ Qxh7 25. Rh3+ Kg4 26. Rxh7 Kxf4 27. Rf7+ Kg4 28. Nd2 Nc6 29. f3+ Kg5 30. Kf2 Nd4 31. Rg1+ Kh6 32. Rh1+ Kg5 33. Ne4# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'mohamad7788',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '21:25:51',
#   '1204',
#   '1545',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Nxe5 Bc5 5. c3 O-O 6. Qb3+ Kh8 7. Nf7+ Kg8 8. Nxd8+ 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'mohamad7788',
#   '0-1',
#   '2013.12.01',
#   '21:27:25',
#   '1526',
#   '1263',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 d5 4. exd5 Nxd5 5. Nc3 Nxc3 6. Bxf7+ Kxf7 7. Nxe5+ Ke6 8. bxc3 Kxe5 9. Qh5+ Kf6 10. O-O g6 11. Qf3+ Kg7 12. c4 Qf6 13. Qb3 Qxa1 14. Bb2+ Qxb2 15. Qxb2+ Kg8 16. Re1 Bf5 17. Re8 h5 18. c5 Kh7 19. Rc8 Bxc8 20. f4 Bg7 21. d4 Bxd4+ 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'great_zaxix',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '21:51:52',
#   '1498',
#   '1272',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Nxe5 Bc5 5. Nd3 Bb6 6. Be2 O-O 7. O-O d5 8. Nc3 Ne4 9. Nxe4 dxe4 10. Ne5 Bxf5 11. c3 Qh4 12. d4 c5 13. Kh1 Nc6 14. f3 cxd4 15. Nxc6 bxc6 16. cxd4 exf3 17. Bxf3 Be4 18. Be3 Bxf3 19. Rxf3 Rxf3 20. Qxf3 Bxd4 21. Bxd4 Qxd4 22. Rf1 Qxb2 23. Qxc6 Rb8 24. h3 Qxa2 25. Qd6 Qb2 26. Qd5+ Kh8 27. Qd6 h6 28. Rd1 a5 29. Qf4 Qb5 30. Qg4 a4 31. Rd7 a3 32. Qxg7# 1-0\n'],
#  ['Rated Classical game',
#   'Time forfeit',
#   'ASTROSCEPTRE',
#   'bijean',
#   '1-0',
#   '2013.12.01',
#   '22:00:57',
#   '1265',
#   '1436',
#   'Italian Game: Schilling-Kostic Gambit',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 Nd4 4. Bxf7+ Kxf7 5. Nxe5+ Ke8 6. Qh5+ g6 7. Nxg6 Nf6 8. Qe5+ Ne6 9. Nxh8 Bg7 10. O-O Bxh8 11. Qg3 Qe7 12. d3 Qg7 13. Qe3 Ng4 14. Qe1 d6 15. Nc3 Bd7 16. Nd5 Qg6 17. f4 Qh5 18. h3 Bd4+ 19. Kh1 Bc6 20. f5 Bxd5 21. exd5 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'bijean',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '22:11:13',
#   '1420',
#   '1289',
#   "Bishop's Opening: Calabrese Countergambit",
#   '1. e4 e5 2. Bc4 f5 3. exf5 Nf6 4. Nf3 d5 5. Bb5+ c6 6. Ba4 b5 7. Bb3 a5 8. a4 Bc5 9. O-O e4 10. d4 exf3 11. dxc5 fxg2 12. Rfe1+ Kf7 13. axb5 Rhf8 14. bxc6 Nxc6 15. Bg5 Ne7 16. Bxf6 Kxf6 17. Qd4+ Kf7 18. f6 gxf6 19. c6 Be6 20. Rxe6 Kxe6 21. Qg4+ Kf7 22. Nc3 Rfg8 23. Qh5+ Kf8 24. Nxd5 Nxd5 25. Bxd5 Rac8 26. Qf7# 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'crizztian',
#   '1-0',
#   '2013.12.01',
#   '22:41:29',
#   '1267',
#   '1401',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 h6 4. Bxf7+ Kxf7 5. Nxe5+ Ke8 6. O-O Qe7 7. d4 Nxe4 8. Ng6 Qf7 9. Nxh8 Qg8 10. Rfe1 Qxh8 11. Rxe4+ Be7 12. Qh5+ Kd8 13. Qf7 Nc6 14. d5 Qh7 15. Ree1 Qxc2 16. dxc6 Qc5 17. Qg8+ Bf8 18. cxd7 Bxd7 19. Be3 Qb4 20. Nc3 c6 21. a3 Qd6 22. Rad1 Qe7 23. Bb6+ axb6 24. Rxe7 Kxe7 25. Re1+ 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'crizztian',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.01',
#   '22:38:51',
#   '1393',
#   '1279',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Nxe5 Bd6 5. Qe2 O-O 6. Qc4+ Kh8 7. Nf7+ Rxf7 8. Qxf7 Nc6 9. Qb3 Nd4 10. Qd3 c5 11. c3 c4 12. Qxd4 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'Sirop',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.02',
#   '15:54:33',
#   '1466',
#   '1508',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Nc3 Bc5 5. Bc4 d5 6. Bb3 e4 7. Nh4 O-O 8. d4 Bb6 9. Na4 Nc6 10. Nxb6 cxb6 11. O-O Qd6 12. g3 a5 13. Bf4 Qd7 14. c4 a4 15. cxd5 Nb4 16. d6+ Kh8 17. Be6 Qb5 18. Bxc8 Raxc8 19. a3 Nd3 20. Qd2 Nxf4 21. Qxf4 Nd5 22. Qxe4 Rce8 23. Qc2 Re2 24. Qd1 Qxb2 25. Qxa4 Re4 26. Rab1 Qxd4 27. Qxd4 Rxd4 28. Rfd1 Rxd1+ 29. Rxd1 Nc3 30. Rd3 Ne4 31. d7 Rd8 32. Nf3 Nc5 33. Rd1 Rxd7 34. Rxd7 Nxd7 35. Nd4 Nc5 36. f4 Kg8 37. Kf2 Kf7 38. Ke2 Ke7 39. Kd2 Ne4+ 40. Kd3 Nc5+ 41. Kc4 Kd6 42. Kb5 Kd5 43. Ne6 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'BS80',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.02',
#   '16:10:04',
#   '1835',
#   '1495',
#   'Latvian Gambit',
#   '1. e4 e5 2. Nf3 f5 3. Nxe5 Nf6 4. exf5 Bc5 5. Bc4 d5 6. Bb3 Bxf5 7. Qe2 O-O 8. O-O Rfe8 9. c3 Bd6 10. d4 b6 11. Bg5 c6 12. Nd2 a5 13. a3 a4 14. Ba2 b5 15. Qf3 Bg6 16. Nxc6 Nxc6 17. Bxd5+ Kh8 18. Bxc6 Bh5 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'bonjour13',
#   '0-1',
#   '2013.12.02',
#   '16:20:48',
#   '1492',
#   '1739',
#   "Bishop's Opening",
#   '1. e4 e5 2. Bc4 h6 3. Nf3 d6 4. Bxf7+ Kxf7 5. Nh4 Qxh4 6. Qf3+ Qf6 7. Qh5+ Qg6 8. Qf3+ Nf6 9. O-O 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'mustroll',
#   '0-1',
#   '2013.12.02',
#   '16:21:53',
#   '1289',
#   '1520',
#   'St. George Defense',
#   '1. e4 a6 2. Bc4 b5 3. Bxf7+ Kxf7 4. Qh5+ g6 5. Qd5+ e6 6. Qd4 Qg5 7. Nf3 Qxg2 8. Ne5+ Ke7 9. Rhf1 Bb7 10. d3 c5 11. Qe3 Bg7 12. Nf3 d6 13. Rfg1 Bd4 14. Qe2 Qh3 15. Bg5+ Kd7 16. Rg3 Qh5 17. Nbd2 Bxb2 18. Rb1 Bc3 19. a4 d5 20. exd5 Bxd5 21. axb5 axb5 22. Rxb5 Ra1+ 23. Rb1 Bxd2+ 24. Kxd2 Rxb1 25. Ne5+ Kd6 26. Nf7+ Kd7 27. Ne5+ Kc7 28. Nf7 Qxe2+ 29. Kxe2 Rb2 30. Nxh8 Rxc2+ 31. Kd1 Rxf2 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'NOBILOS3',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.02',
#   '16:27:31',
#   '1539',
#   '1487',
#   "King's Pawn Game: Wayward Queen Attack",
#   '1. e4 e5 2. Qh5 Nc6 3. c3 Nf6 4. Qf3 d6 5. h3 Be7 6. a4 O-O 7. Bc4 Be6 8. d3 Bxc4 9. dxc4 Nd7 10. b4 d5 11. cxd5 Ncb8 12. Ne2 c6 13. Ba3 cxd5 14. exd5 Bd6 15. O-O Rfe8 16. Qe4 Nf6 17. Qe3 Nxd5 18. Qd3 Nf6 19. Ng3 Qc7 20. Nf5 e4 21. Qxd6 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'rikpal',
#   '0-1',
#   '2013.12.02',
#   '16:32:37',
#   '1282',
#   '1641',
#   'Scandinavian Defense',
#   '1. e4 d5 2. e5 c5 3. Nf3 Nc6 4. Bb5 Bf5 5. O-O e6 6. Ng5 Be7 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'quez',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.02',
#   '16:33:35',
#   '1454',
#   '1279',
#   'Danish Gambit',
#   '1. e4 e5 2. d4 exd4 3. c3 Bc5 4. cxd4 Bb6 5. Bc4 Ne7 6. Qg4 O-O 7. Bh6 Ng6 8. Bg5 Qe8 9. e5 d5 10. Bd3 Bxg4 11. Bxg6 fxg6 12. f3 Bxd4 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'Walter1',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.02',
#   '19:22:25',
#   '1618',
#   '1301',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Nxe5 Bc5 5. d4 Bd6 6. Nf3 O-O 7. Bd3 Be7 8. O-O d5 9. Bg5 Ng4 10. Bxe7 Qxe7 11. Rfe1 Qf6 12. h3 Nh6 13. Nc3 c6 14. Re2 Nxf5 15. Bxf5 Bxf5 16. Qe1 Nd7 17. Ne5 Nxe5 18. Rxe5 Qg6 19. g4 Bxc2 20. Rc1 Bd3 21. Re7 b5 22. b4 a5 23. bxa5 Rxa5 24. Qe3 Bc4 25. Rce1 Ra3 26. Re7e8 b4 27. Rxf8+ Kxf8 28. Qe7+ Kg8 29. Qd8+ Kf7 30. Re7+ Kf6 31. Ra7+ Ke6 32. Qe7# 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'nunutsu',
#   '1-0',
#   '2013.12.02',
#   '19:31:29',
#   '1297',
#   '1256',
#   'Philidor Defense #3',
#   '1. e4 e5 2. Bc4 d6 3. Nf3 Qe7 4. d3 h6 5. O-O g5 6. Nc3 g4 7. Nd5 Qd8 8. Ne1 h5 9. f3 h4 10. fxg4 Nh6 11. Nf6+ Ke7 12. Bg5 Bg7 13. Nd5+ Kd7 14. Bxd8 Kxd8 15. g5 Ng8 16. Rxf7 h3 17. Rxg7 hxg2 18. Nxc7 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'bobek123',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.02',
#   '19:37:05',
#   '1530',
#   '1310',
#   "King's Pawn Game: Wayward Queen Attack",
#   '1. e4 e5 2. Qh5 Nc6 3. c3 g6 4. Qf3 Be7 5. Bc4 Nf6 6. h3 O-O 7. d3 d5 8. exd5 Nxd5 9. Bxd5 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'bobek123',
#   '0-1',
#   '2013.12.02',
#   '19:38:55',
#   '1303',
#   '1535',
#   "Bishop's Opening: Boi Variation",
#   '1. e4 e5 2. Bc4 Bc5 3. Nf3 c6 4. Bxf7+ Kxf7 5. Nxe5+ Ke6 6. f4 Qf6 7. Qg4+ Kd6 8. Nc4+ Kc7 9. c3 b5 10. d4 d5 11. O-O Bxg4 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'rikpal',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.02',
#   '19:43:40',
#   '1594',
#   '1297',
#   'Dutch Defense',
#   '1. d4 f5 2. e3 Nf6 3. c3 d5 4. Bd3 e6 5. f3 Bd6 6. Nd2 O-O 7. e4 dxe4 8. fxe4 fxe4 9. Nxe4 Nxe4 10. Bxe4 Qh4+ 11. g3 Qxe4+ 12. Qe2 Qxh1 13. Qe3 Qxh2 14. Ne2 e5 15. Bd2 Qh1+ 16. Ng1 exd4 17. cxd4 Bg4 18. Bc3 Nc6 19. Kd2 Rae8 20. Qd3 Qg2+ 21. Ne2 Rxe2+ 22. Qxe2 Qxe2+ 23. Kc1 Rf1+ 24. Be1 Rxe1# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'cegal',
#   '1-0',
#   '2013.12.02',
#   '19:49:50',
#   '1477',
#   '1449',
#   'Italian Game: Two Knights Defense',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 Nc6 4. Bxf7+ Kxf7 5. Ng5+ Ke8 6. d4 exd4 7. O-O Be7 8. e5 Nd5 9. Qh5+ g6 10. Qg4 Nxe5 11. Qxd4 Bxg5 12. Qxe5+ Qe7 13. Qxd5 Bxc1 14. Rfxc1 d6 15. Nc3 Rhf8 16. Rce1 Qxe1+ 17. Rxe1+ Kd8 18. Qg5+ Kd7 19. Qe7+ Kc6 20. Qxf8 b5 21. Qe8+ Kb6 22. Nd5+ Kb7 23. Qd8 Kc6 24. Rd1 Kb7 25. Qxc7+ Ka6 26. Nb4# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'vurdalak',
#   '1-0',
#   '2013.12.02',
#   '20:02:55',
#   '1488',
#   '1645',
#   "Bishop's Opening",
#   '1. e4 e5 2. Bc4 Qf6 3. Nf3 Bc5 4. d3 h6 5. Nc3 a5 6. Nd5 Qd6 7. Nc3 c6 8. Nh4 b5 9. Bxf7+ Kf8 10. Bxg8 Rhxg8 11. Qf3+ Qf6 12. O-O d6 13. Qh5 Be6 14. Ng6+ Ke8 15. Nxe5+ Ke7 16. Nf3 Nd7 17. d4 Bf7 18. Qh3 Be6 19. Qg3 Bxd4 20. Nxd4 Qxd4 21. Be3 Qf6 22. Rad1 Ne5 23. Bd4 Bc4 24. Bxe5 dxe5 25. Rfe1 Rad8 26. b3 Rxd1 27. Rxd1 Be6 28. Qe3 Kf7 29. Qa7+ Kg6 30. Qxa5 Bg4 31. Rf1 Qf4 32. Qb6 Rc8 33. Qc5 h5 34. Qd6+ Kh7 35. h3 Bxh3 36. Ne2 Qg5 37. Ng3 Bg4 38. f3 Bh3 39. Kh2 h4 40. gxh3 Qxg3+ 41. Kh1 Qxh3+ 42. Kg1 Qg3+ 43. Kh1 h3 44. Rg1 Qxf3+ 45. Kh2 Qf2+ 46. Kh1 h2 47. Qg6+ Kg8 48. Qxg7# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'vurdalak',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.02',
#   '20:22:34',
#   '1625',
#   '1505',
#   'Latvian Gambit: Mlotkowski Variation',
#   '1. e4 e5 2. Nf3 f5 3. Nc3 Nf6 4. exf5 Bc5 5. Qe2 O-O 6. d3 Rfe8 7. Bg5 d6 8. O-O-O Nbd7 9. h4 a5 10. h5 h6 11. Bxf6 Nxf6 12. Nh4 Bxf5 13. f3 a4 14. Nxf5 a3 15. b3 Bd4 16. Ne4 Bb2+ 17. Kb1 Nxe4 18. fxe4 c5 19. Qg4 Re7 20. Nxh6+ Kh8 21. Nf5 c4 22. dxc4 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'DrunkNinja',
#   '1-0',
#   '2013.12.02',
#   '20:28:57',
#   '1497',
#   '1350',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 Bc5 4. Bxf7+ Kxf7 5. Nxe5+ Ke8 6. d4 Bxd4 7. Qxd4 d6 8. Nf3 Qe7 9. O-O Nxe4 10. Rfe1 Bf5 11. Bg5 Qd7 12. Nh4 h6 13. Nxf5 hxg5 14. Rxe4+ Kf8 15. Re7 Qxf5 16. Qxg7# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'DrunkNinja',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.02',
#   '20:34:18',
#   '1343',
#   '1504',
#   'Dutch Defense',
#   '1. d4 f5 2. Nf3 Nf6 3. Nc3 d5 4. Bg5 Ng4 5. e3 h6 6. Bf4 g5 7. Bg3 Nc6 8. Bb5 a6 9. Bxc6+ bxc6 10. O-O h5 11. Nxg5 h4 12. Bxh4 Rxh4 13. Qf3 Nxh2 14. Qg3 Rg4 15. Qxh2 Rxg5 16. Qh8 Qd6 17. f4 Rg7 18. Qh5+ Kd8 19. g3 Be6 20. Ne2 Kd7 21. c3 c5 22. b3 cxd4 23. Nxd4 c5 24. Nxf5 Bxf5 25. Qxf5+ Kd8 26. Qxf8+ Kd7 27. Qxg7 d4 28. exd4 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'tesan',
#   '1-0',
#   '2013.12.02',
#   '20:44:05',
#   '1487',
#   '1721',
#   'Italian Game: Two Knights Defense',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 Nf6 4. Bxf7+ Kxf7 5. Ng5+ Ke8 6. O-O h6 7. Nf3 d6 8. h3 Be7 9. d4 Nxe4 10. Nfd2 Nxd2 11. Qh5+ g6 12. Qxg6+ Kf8 13. Bxd2 Nxd4 14. Bxh6+ Rxh6 15. Qxh6+ Ke8 16. Na3 Bf5 17. Qh5+ Kd7 18. c3 Nc6 19. Qxf5+ Ke8 20. f4 d5 21. fxe5 Bc5+ 22. Kh1 Qe7 23. Qh5+ Kd7 24. Rae1 Rf8 25. Rxf8 Qxf8 26. e6+ Kd6 27. Nb5+ Ke7 28. Nxc7 Bd6 29. Nxd5+ Kd8 30. c4 b6 31. a3 Kc8 32. b4 Qf2 33. Qe8+ Kb7 34. Qd7+ Ka6 35. b5+ Ka5 36. Qxd6 Qxe1+ 37. Kh2 Nd4 38. Qb4+ Qxb4 39. axb4+ Ka4 40. e7 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'tpsinnem',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.02',
#   '21:04:07',
#   '1534',
#   '1506',
#   "English Opening: King's English Variation, Reversed Sicilian",
#   '1. c4 e5 2. Nc3 f5 3. e4 Nf6 4. Qf3 Bc5 5. Qxf5 d6 6. Qf3 O-O 7. h3 Ng4 8. Qd3 Nxf2 9. Qd5+ Kh8 10. Rh2 Qh4 11. g3 Qxg3 12. Rg2 Nd3+ 13. Kd1 Rxf1+ 14. Kc2 Nb4+ 15. Kb3 Qxg2 16. Nge2 Nxd5 17. cxd5 Bd4 18. Nxd4 exd4 19. Nb5 Qxh3+ 20. Kc2 d3+ 21. Kc3 a5 22. Nxc7 Ra7 23. Nb5 Ra6 24. b3 Rb6 25. Nc7 Rb4 26. Bb2 Rxe4 27. Rxf1 Qxf1 28. Nb5 Qf6+ 29. Kxd3 Qf3+ 30. Kc2 Bf5 31. Bc3 Re2+ 32. Kc1 Re1+ 33. Kb2 Qd3 34. Nd4 Rb1+ 35. Ka3 a4 36. b4 Nd7 37. b5 Nb6 38. Nxf5 Nc4+ 39. Kxa4 Qc2# 0-1\n'],
#  ['Rated Blitz game',
#   'Time forfeit',
#   'lzm994',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.02',
#   '21:41:54',
#   '1499',
#   '1322',
#   'Vienna Game',
#   '1. e4 e5 2. Nc3 f5 3. exf5 Bb4 4. Qe2 Nf6 5. Qxe5+ Kf7 6. Bc4+ d5 7. Bxd5+ Nxd5 8. Nxd5 Rhe8 9. Nf3 Rxe5+ 10. Nxe5+ Kg8 11. Nxb4 Qe8 12. d4 Bxf5 13. O-O Nc6 14. Nbxc6 bxc6 15. c3 Qh5 16. f3 c5 17. g4 Bxg4 18. fxg4 Qh4 19. Rf4 Qe1+ 20. Rff1 Qe4 21. h3 cxd4 22. Bd2 Qxe5 23. Rae1 Qc5 24. Rf5 Qb6 25. Kh1 dxc3 26. Bxc3 Qc6+ 27. Kh2 g6 28. Rf6 Qb7 29. Ref1 Qd5 30. a3 c5 31. Re1 Rc8 32. Re7 Rf8 33. Re5 Qd7 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'amadorsouza',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.02',
#   '22:02:40',
#   '1260',
#   '1343',
#   'Dutch Defense: Raphael Variation',
#   '1. d4 f5 2. Nc3 Nf6 3. Bf4 d5 4. Nb5 Na6 5. c3 c6 6. Na3 e6 7. Nf3 Bxa3 8. bxa3 O-O 9. Ne5 Ng4 10. Nd3 c5 11. dxc5 Rfe8 12. c6 bxc6 13. h3 e5 14. hxg4 exf4 15. Nxf4 fxg4 16. g3 c5 17. Bg2 Rab8 18. Qa4 Nc7 19. Rad1 Rb2 20. c4 d4 21. Nd3 Rbxe2+ 22. Kf1 Qf6 23. Qa5 Qf7 24. Rde1 Re2xe1+ 25. Nxe1 Rf8 26. Nd3 Bf5 27. Ne5 Qe7 28. Nc6 Qf6 29. Qxc5 Bd3+ 30. Kg1 Qxf2+ 31. Kh2 Ne6 32. Qe5 Bf5 33. Qd5 Qxa2 34. Nxd4 Rd8 35. Qe5 Nxd4 36. Re1 Nf3+ 37. Kh1 Nxe5 38. Rxe5 Rf8 39. Kg1 Qb1+ 40. Bf1 Bd3 41. Re1 Qxe1 42. Kg2 Qxf1+ 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'Saltytar',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.02',
#   '22:19:47',
#   '1422',
#   '1518',
#   "King's Pawn Game: Macleod Attack, Lasa Gambit",
#   '1. e4 e5 2. c3 f5 3. exf5 Nf6 4. Be2 d5 5. Bh5+ Ke7 6. Qb3 Bxf5 7. Qb4+ Qd6 8. Qh4 Nc6 9. Qg5 g6 10. Bf3 e4 11. Be2 Ne5 12. d3 Nxd3+ 13. Bxd3 exd3 14. Qxf5 0-1\n'],
#  ['Rated Classical game',
#   'Time forfeit',
#   'mazorra',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.02',
#   '22:27:04',
#   '1647',
#   '1526',
#   "Bishop's Opening: Calabrese Countergambit",
#   '1. e4 e5 2. Bc4 f5 3. exf5 Nf6 4. Nc3 d5 5. Bb3 Bc5 6. Qf3 c6 7. d3 O-O 8. Bg5 Be7 9. h4 a5 10. a3 b5 11. Qg3 a4 12. Ba2 Na6 13. h5 h6 14. Bxh6 Rf7 15. Bg5 Nh7 16. Bxe7 Qxe7 17. O-O-O Bxf5 18. Nf3 b4 19. Nxa4 bxa3 20. b3 Nb4 21. Kb1 Rxa4 22. bxa4 Qc5 23. Rdc1 Qc3 24. Qxe5 Qc5 25. c3 Na6 26. Rhe1 Qb6+ 27. Kc2 Qb2+ 28. Kd1 Qxa2 29. Nd2 Bxd3 30. Qe8+ Nf8 31. Qxc6 Rc7 32. Qxa6 Bxa6 33. Re8 d4 34. c4 Bxc4 35. Rb8 Bd3 36. Rxf8+ Kxf8 37. Rxc7 Qa1+ 38. Rc1 Qb2 39. f3 a2 40. a5 a1=Q 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'mazorra',
#   '1-0',
#   '2013.12.02',
#   '22:47:44',
#   '1541',
#   '1633',
#   "Bishop's Opening: Boi Variation",
#   '1. e4 e5 2. Bc4 Bc5 3. Nf3 d6 4. Bxf7+ Kxf7 5. d4 Nf6 6. Ng5+ Ke8 7. dxc5 h6 8. Nf3 Nxe4 9. O-O Nxc5 10. Nc3 Nc6 11. Nd5 Be6 12. c4 Bxd5 13. cxd5 Nd4 14. Nxd4 exd4 15. Qh5+ Kd7 16. Qf7+ Kc8 17. Qxg7 b6 18. Qxd4 Kb7 19. b4 Na6 20. a4 Rac8 21. a5 Kb8 22. axb6 c5 23. bxa7+ Ka8 24. bxc5 Nxc5 25. Ba3 Nb3 26. Qd1 Nxa1 27. Qxa1 Qa5 28. Qb2 Qa6 29. Ra1 Rc7 30. Qxh8+ Kxa7 31. Bxd6 Qxa1+ 32. Qxa1+ Kb6 33. Bxc7+ Kxc7 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'kroke',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.03',
#   '19:50:56',
#   '1471',
#   '1556',
#   'Center Game: Normal Variation',
#   '1. e4 e5 2. d4 exd4 3. Qxd4 Nc6 4. Qa4 f5 5. a3 Nf6 6. Nc3 Bc5 7. Bg5 O-O 8. Bxf6 Qxf6 9. Nd5 Qg5 10. Nf3 Qh6 11. Bb5 fxe4 12. Bxc6 exf3 13. Bxb7 Bxb7 14. Nxc7 Rac8 15. Qc4+ d5 16. Qxc5 fxg2 17. Rhg1 Rf7 18. Nxd5 Rxc5 0-1\n'],
#  ['Rated Bullet game',
#   'Normal',
#   'BrutS',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.03',
#   '20:00:08',
#   '1899',
#   '1078',
#   'Zukertort Opening: Dutch Variation',
#   '1. Nf3 f5 2. g3 Nf6 3. Bg2 d5 4. d4 e6 5. O-O Bd6 6. b3 O-O 7. Ba3 a6 8. c4 Bxa3 9. Nxa3 b5 10. cxb5 axb5 11. Nxb5 c6 12. Nc3 Nbd7 13. Na4 Bb7 14. Rac1 Qa5 15. Rc2 Ne4 16. Qc1 Nb6 17. Nc5 Nc8 18. Nxb7 Ra7 19. Nc5 Raf7 20. Ne5 f4 21. Nxf7 Rxf7 22. Nxe4 dxe4 23. Bxe4 f3 24. Bxf3 e5 25. dxe5 Rxf3 26. exf3 Qxe5 27. Re1 Qf6 28. Kg2 Kf7 29. Rxc6 Qe5 30. Qc4+ Ke8 31. Rxe5+ 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'patrisha',
#   '0-1',
#   '2013.12.03',
#   '19:57:44',
#   '1565',
#   '1817',
#   'Pirc Defense #4',
#   '1. e4 d6 2. Bc4 e6 3. Nf3 a6 4. O-O b5 5. Be2 Bb7 6. d3 Be7 7. e5 Nd7 8. exd6 cxd6 9. Nd4 Ngf6 10. Bg5 O-O 11. Bxf6 Bxf6 12. f4 0-1\n'],
#  ['Rated Bullet game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'BrutS',
#   '0-1',
#   '2013.12.03',
#   '20:03:12',
#   '1076',
#   '1899',
#   'Pirc Defense #4',
#   '1. e4 d6 2. Bc4 Nf6 3. Nf3 Nxe4 4. Bxf7+ Kxf7 5. d3 Nf6 6. Ng5+ Kg8 7. O-O e5 8. f4 Nc6 9. c3 h6 10. Qb3+ d5 11. fxe5 Nxe5 12. d4 Nc4 13. Qd1 hxg5 14. Bxg5 Bd6 15. Bxf6 Bxh2+ 16. Kf2 Qxf6+ 17. Ke1 Bg3+ 18. Ke2 Bg4+ 19. Kd3 Bxd1 20. Rfxd1 Qf5+ 21. Ke2 Rae8# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'hoth_and_guderian',
#   '0-1',
#   '2013.12.03',
#   '20:08:19',
#   '1560',
#   '1609',
#   "Bishop's Opening",
#   '1. e4 e5 2. Bc4 c5 3. Nf3 d6 4. O-O Nf6 5. d3 h6 6. Bxf7+ Kxf7 7. Nh4 Bg4 8. f4 Bxd1 9. fxe5 dxe5 10. Rfxd1 Qd4+ 11. Kh1 Nxe4 12. Nf5 Nf2+ 13. Kg1 Nh3+ 14. Kh1 Qf2 15. gxh3 Qf3+ 16. Kg1 Qxd1+ 17. Kf2 Qxc1 18. Ne3 0-1\n'],
#  ['Rated Blitz game',
#   'Time forfeit',
#   'ASTROSCEPTRE',
#   'user1972',
#   '0-1',
#   '2013.12.03',
#   '20:16:57',
#   '1354',
#   '1498',
#   'Philidor Defense #3',
#   '1. e4 e5 2. Bc4 d6 3. Nf3 Nh6 4. d3 Bg4 5. h3 Bh5 6. g4 Bg6 7. Bxf7+ Bxf7 8. g5 Ng8 9. Bd2 Bg6 10. Nc3 Be7 11. h4 Nc6 12. h5 Bf7 13. Qe2 Be6 14. O-O-O Qd7 15. Be3 O-O-O 16. Nb5 a6 17. Na7+ Kb8 18. Nb5 axb5 19. d4 exd4 20. Bxd4 Nxd4 21. Rxd4 c5 22. Rdd1 Bg4 23. Qd3 Bxf3 24. Qxf3 Bxg5+ 25. Kb1 Bh6 26. e5 d5 27. Rhe1 Qe6 28. Qb3 b4 29. Qa4 Ne7 30. f4 Nc6 31. f5 Qxf5 32. e6 Rhe8 33. Ka1 Qxh5 34. c4 d4 35. Qb5 Be3 36. Qb6 Rxe6 37. Qa5 Ree8 38. Qb5 Qh2 39. Qxc5 Ref8 40. Qb5 Rf2 41. Reh1 Qg2 42. Rhg1 Qf3 43. Rdb1 Qf4 44. c5 Rc2 45. Qa4 Bxg1 46. Qxc2 Be3 47. Qd1 Rf8 0-1\n'],
#  ['Rated Blitz game',
#   'Time forfeit',
#   'rikpal',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.03',
#   '20:31:21',
#   '1534',
#   '1345',
#   'Dutch Defense',
#   '1. d4 f5 2. Nf3 Nf6 3. Nc3 d5 4. e3 e6 5. Nd2 Bb4 6. f3 O-O 7. Bd3 Nc6 8. a3 Bxc3 9. bxc3 e5 10. dxe5 Nxe5 11. f4 Neg4 12. Nf3 a6 13. h3 Nh6 14. Nh4 Qe8 15. c4 Nh5 16. cxd5 Ng3 17. Qf3 Nxh1 18. Ke2 c5 19. Bd2 b5 20. c4 bxc4 21. Bxc4 Kh8 22. Rxh1 Qa4 23. Bd3 Qxa3 24. g4 Bb7 25. g5 Nf7 26. Nxf5 c4 27. Bxc4 Rac8 28. Qe4 Qa4 29. Qe7 Qxc4+ 30. Kf3 Bxd5+ 31. e4 Rce8 32. Qa3 Qxe4+ 33. Kg4 h5+ 34. Kxh5 g6+ 35. Kg4 gxf5+ 36. Kh5 Kg7 37. Qxf8+ Rxf8 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'boord',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.03',
#   '20:39:34',
#   '1520',
#   '1550',
#   'Latvian Gambit: Mlotkowski Variation',
#   '1. e4 e5 2. Nf3 f5 3. Nc3 Nf6 4. exf5 Bc5 5. h3 O-O 6. d4 exd4 7. Nxd4 Rfe8+ 8. Be2 d5 9. O-O Nc6 10. Ne6 Bxe6 11. fxe6 Rxe6 12. Bg4 Ree8 13. Qf3 d4 14. Ne2 Nxg4 15. Qxg4 Ne5 16. Qg3 d3 17. cxd3 Nxd3 18. Bg5 Qd6 19. Qxd6 Bxd6 20. Rfe1 Nxe1 0-1\n'],
#  ['Rated Bullet game',
#   'Time forfeit',
#   'ASTROSCEPTRE',
#   'jurdy',
#   '0-1',
#   '2013.12.03',
#   '20:49:28',
#   '1075',
#   '1543',
#   'Modern Defense',
#   '1. e4 g6 2. Bc4 Bg7 3. d3 e6 4. Bd2 Ne7 5. Qe2 b6 6. Nf3 Bb7 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'janoi',
#   '0-1',
#   '2013.12.03',
#   '20:51:58',
#   '1561',
#   '1700',
#   "Bishop's Opening: Boi Variation",
#   '1. e4 e5 2. Bc4 Bc5 3. Nf3 d6 4. O-O Nc6 5. Bxf7+ Kxf7 6. d4 exd4 7. Ng5+ Ke8 8. f4 h6 9. Qh5+ Kd7 10. e5 Qe8 11. e6+ Ke7 12. f5 Qxh5 13. f6+ gxf6 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'janoi',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.03',
#   '20:55:10',
#   '1709',
#   '1554',
#   'Budapest Defense: Adler Variation',
#   '1. d4 Nf6 2. c4 e5 3. dxe5 Ng4 4. Nf3 Bc5 5. e3 O-O 6. h3 Nxf2 7. Kxf2 d5 8. cxd5 f5 9. Bc4 Kh8 10. Nc3 a6 11. Rhe1 b5 12. Bb3 f4 13. Ne4 fxe3+ 14. Bxe3 Bxe3+ 15. Rxe3 Rxf3+ 16. Rxf3 Qh4+ 17. Kg1 h6 18. Ng3 Bxh3 19. Rf8+ Kh7 20. Bc2+ g6 21. Qf3 Nd7 22. Qf7# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'janoi',
#   '0-1',
#   '2013.12.03',
#   '20:59:55',
#   '1547',
#   '1718',
#   "Bishop's Opening: Boi Variation",
#   '1. e4 e5 2. Bc4 Bc5 3. Nf3 d6 4. Bxf7+ Kxf7 5. d4 exd4 6. Ng5+ Kf8 7. Qf3+ Qf6 8. Qg3 h6 9. e5 dxe5 10. O-O hxg5 11. Bxg5 Qf5 12. f4 d3+ 13. Kh1 dxc2 14. Nc3 e4 15. Rae1 e3 16. Nb5 Bb6 17. Nxc7 Bxc7 18. Rxe3 Nc6 19. Re5 0-1\n'],
#  ['Rated Bullet game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'ognjen',
#   '1-0',
#   '2013.12.03',
#   '21:05:47',
#   '1066',
#   '1431',
#   'Modern Defense',
#   '1. e4 g6 2. Bc4 Bg7 3. Nf3 e6 4. d4 b6 5. d5 Qe7 6. dxe6 dxe6 7. O-O Nf6 8. e5 Nd5 9. Bg5 f6 10. exf6 Bxf6 11. Bxf6 Qxf6 12. Bb5+ Bd7 13. Bxd7+ Nxd7 14. c3 O-O-O 15. Nd4 g5 16. Nc6 Rdf8 17. Nxa7+ Kb7 18. Nb5 h5 19. c4 Nf4 20. c5 Nxc5 21. b4 Qxa1 22. bxc5 Qxa2 23. c6+ Kxc6 24. Qc1+ Kb7 25. Qxc7+ Ka8 26. Qc6+ Kb8 27. Qxb6+ Ka8 28. Qc6+ Kb8 29. Qb6+ Ka8 30. Nc7# 1-0\n'],
#  ['Rated Bullet game',
#   'Time forfeit',
#   'ASTROSCEPTRE',
#   'ognjen',
#   '0-1',
#   '2013.12.03',
#   '21:09:34',
#   '1175',
#   '1414',
#   'Modern Defense',
#   '1. e4 g6 2. Bc4 Bg7 3. Nf3 Nc6 4. Bxf7+ Kxf7 5. Ng5+ Ke8 6. O-O Bf6 7. d4 Nxd4 8. c3 Ne6 9. Nxe6 dxe6 10. Qe2 Qd6 11. f4 e5 12. Na3 Bd7 13. Nc4 Qa6 14. b3 Bb5 15. fxe5 Bxe5 16. Qf3 Nf6 17. Bg5 Bxc4 18. bxc4 Qxc4 19. Bxf6 Bxf6 20. e5 Qc5+ 21. Kh1 Qxe5 22. Qxb7 Kf7 23. Qxc7 Rac8 24. Qxe5 Rc6 25. Qd5+ Re6 26. Qb7 Rd8 27. Qxa7 Rdd6 28. Qa4 Rda6 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'OCTALIS',
#   '1-0',
#   '2013.12.04',
#   '15:18:26',
#   '1541',
#   '1280',
#   'Owen Defense',
#   '1. e4 b6 2. Bc4 Bb7 3. Nf3 Nf6 4. Bxf7+ Kxf7 5. Ng5+ Kg8 6. e5 h6 7. exf6 hxg5 8. f7+ Kxf7 9. O-O e6 10. f4 Ke8 11. fxg5 Qxg5 12. Rf2 Rxh2 13. Qf1 Bc5 14. d4 Bxd4 15. Bxg5 Rhh8 16. Nd2 Bxb2 17. Rd1 Bd4 18. Nb3 Rh2 19. Nxd4 Rxg2+ 20. Rxg2 Bxg2 21. Qxg2 Nc6 22. Nxc6 dxc6 23. Qxc6+ Kf7 24. Qxa8 a5 25. Rf1+ Kg6 26. Qe4+ Kxg5 27. Qg2+ Kh6 28. Rf3 Kh7 29. Rh3+ Kg8 30. Qg6 c5 31. Rg3 b5 32. Qxg7# 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ivaja',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.04',
#   '15:39:20',
#   '1372',
#   '1366',
#   'Dutch Defense',
#   '1. d4 f5 2. Nf3 Nf6 3. Bg5 d5 4. Bxf6 exf6 5. Nc3 c6 6. Nh4 Be7 7. Qd3 O-O 8. Nxf5 Bxf5 9. Qxf5 Nd7 10. e4 dxe4 11. Nxe4 Nb6 12. O-O-O a5 13. Bd3 a4 14. Nc5 a3 15. b3 Bxc5 16. Qxh7+ Kf7 17. Bc4+ Ke8 18. dxc5 Qc7 19. Qg6+ 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'ivaja',
#   '1-0',
#   '2013.12.04',
#   '15:45:07',
#   '1353',
#   '1383',
#   'Owen Defense',
#   '1. e4 b6 2. Bc4 Bb7 3. Nf3 Bxe4 4. Bxf7+ Kxf7 5. Ne5+ Ke6 6. Qg4+ Bf5 7. Qe2 Kf6 8. O-O Nc6 9. f4 d6 10. Nxc6 Qd7 11. Nd4 c5 12. Nxf5 Qxf5 13. b3 Qxc2 14. Qg4 Qf5 15. Bb2+ e5 16. fxe5+ Ke6 17. Qxf5+ Ke7 18. e6 Nf6 19. Bxf6+ gxf6 20. Qxf6+ Ke8 21. Qxh8 Rd8 22. Qxh7 d5 23. Qf7# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   '____________',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.04',
#   '16:44:29',
#   '1462',
#   '1545',
#   "King's Pawn Game: Wayward Queen Attack",
#   '1. e4 e5 2. Qh5 d6 3. Bc4 g6 4. Qf3 Nf6 5. d4 Bg4 6. Qg3 Qd7 7. Bg5 Nxe4 8. Qh4 Nxg5 9. Qxg5 Be7 10. Qh6 Nc6 11. Qg7 O-O-O 12. dxe5 Nxe5 13. Bxf7 Qc6 14. f3 Qxc2 15. fxg4 Qxg2 16. Be6+ Kb8 17. Qxe7 Nd3+ 18. Kd1 Nxb2+ 19. Kc1 Nd3+ 20. Kd1 Qxh1 21. Kd2 Rhe8 22. Qf6 Nc5 23. Bf7 Qg2+ 24. Kc1 Qxg1+ 25. Kb2 Qg2+ 26. Kc1 Re1# 0-1\n'],
#  ['Rated Blitz game',
#   'Time forfeit',
#   'bianco-e4',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.04',
#   '17:05:13',
#   '1409',
#   '1367',
#   'Latvian Gambit',
#   '1. e4 { [%eval 0.18] } 1... e5 { [%eval 0.2] } 2. Nf3 { [%eval 0.3] } 2... f5?! { [%eval 1.27] } 3. Nxe5 { [%eval 1.07] } 3... Nf6 { [%eval 1.49] } 4. Bc4 { [%eval 1.57] } 4... d5? { [%eval 2.76] } 5. exd5 { [%eval 2.78] } 5... Bd6 { [%eval 2.86] } 6. f4?! { [%eval 2.2] } 6... O-O?! { [%eval 2.82] } 7. h3? { [%eval 1.61] } 7... Nbd7 { [%eval 1.63] } 8. Nc3?! { [%eval 0.64] } 8... Nxe5 { [%eval 0.82] } 9. fxe5 { [%eval 0.96] } 9... Bxe5 { [%eval 0.82] } 10. Ne2? { [%eval -0.22] } 10... Ne4?! { [%eval 0.52] } 11. Rhf1?? { [%eval -26.66] } 11... Qh4+ { [%eval #-8] } 12. g3 { [%eval #-5] } 12... Nxg3? { [%eval -8.52] } 13. d6+? { [%eval -9.71] } 13... Kh8? { [%eval -7.73] } 14. d7? { [%eval #-6] } 14... Nxf1+?! { [%eval -12.4] } 15. Kxf1 { [%eval -12.96] } 15... Qxh3+ { [%eval -13.45] } 16. Ke1 { [%eval -18.74] } 16... Bxd7?! { [%eval -9.13] } 17. d4 { [%eval -9.47] } 17... Qh4+ { [%eval -9.57] } 18. Kd2 { [%eval -9.57] } 18... Bd6? { [%eval -7.47] } 19. c3? { [%eval -10.24] } 19... f4 { [%eval -8.24] } 20. Kc2? { [%eval -11.17] } 20... f3 { [%eval -10.28] } 21. Ng1 { [%eval -11.43] } 21... f2 { [%eval -11.73] } 22. Nf3 { [%eval -12.96] } 22... Qe4+ { [%eval -12.96] } 23. Bd3 { [%eval -13.27] } 23... Qxf3 { [%eval -13.71] } 24. Qxf3 { [%eval -15.19] } 24... Rxf3 { [%eval -14.74] } 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'ojeh',
#   '0-1',
#   '2013.12.04',
#   '17:13:37',
#   '1554',
#   '1642',
#   'Scotch Game: Haxo Gambit',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 Bc5 4. d4 exd4 5. Bxf7+ Kxf7 6. Ng5+ Ke8 7. Qh5+ g6 8. Qf3 Qe7 9. O-O Ne5 10. Qb3 d6 11. f4 Nc6 12. e5 Na5 13. Qf3 Bd7 14. exd6 cxd6 15. Bd2 Kd8 16. Bxa5+ Kc8 17. Nd2 Bc6 18. Qb3 b6 19. Rae1 Qd7 20. Bb4 Bb5 21. Rf2 Nf6 22. Bxc5 dxc5 23. c4 Bc6 24. Rfe2 Ng4 25. Re2e7 Qf5 26. Nf7 Rhd8 27. Nxd8 Kxd8 28. Rxh7 Qxf4 29. Rh8+ Kc7 30. Rxa8 Qxh2+ 31. Kf1 Qxg2# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'parque',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.04',
#   '17:26:41',
#   '1467',
#   '1545',
#   'Latvian Gambit Accepted',
#   '1. e4 e5 2. Nf3 f5 3. exf5 Nf6 4. Bc4 Bc5 5. O-O d5 6. Bb3 O-O 7. d4 exd4 8. Nxd4 Bxf5 9. Nxf5 Ne4 10. Be3 Bxe3 11. Nxe3 Nxf2 12. Rxf2 Rxf2 13. Kxf2 Qh4+ 14. Kg1 Nc6 15. Qxd5+ Kh8 16. Nc3 Rf8 17. Nf5 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'caramba',
#   '0-1',
#   '2013.12.04',
#   '17:34:02',
#   '1531',
#   '1565',
#   'Sicilian Defense: Bowdler Attack',
#   '1. e4 c5 2. Bc4 e6 3. Nf3 a6 4. d4 b5 5. Bd3 cxd4 6. Ne5 Qc7 7. Nxf7 Kxf7 8. Qf3+ Nf6 9. O-O Be7 10. Rfe1 e5 11. c4 bxc4 12. Be2 Rhf8 13. Bg5 Kg8 14. Qg3 Nxe4 15. Qh4 Nxg5 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'rama66',
#   '0-1',
#   '2013.12.04',
#   '17:37:06',
#   '1521',
#   '1352',
#   'Borg Defense',
#   '1. e4 g5 2. Bc4 h6 3. Nf3 Bg7 4. e5 e6 5. d4 Nc6 6. O-O Nge7 7. Nc3 a6 8. Ne4 O-O 9. Nf6+ Bxf6 10. exf6 Ng6 11. Bd3 Qxf6 12. Bxg6 Qxg6 13. Ne5 Nxe5 14. dxe5 Qg7 15. f4 d5 16. fxg5 hxg5 17. Rf3 Qxe5 18. Rg3 f6 19. Qh5 Qe1# 0-1\n'],
#  ['Rated Classical game',
#   'Time forfeit',
#   'sodafreak',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.04',
#   '17:59:08',
#   '1337',
#   '1505',
#   'Dutch Defense: Raphael Variation',
#   '1. d4 f5 2. Nc3 Nf6 3. e4 Ng4 4. exf5 Nxf2 5. Kxf2 e6 6. Qh5+ g6 7. Qg4 Qf6 8. Bd3 exf5 9. Qe2+ Be7 10. Nf3 O-O 11. Be3 c6 12. Ng5 d5 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'tesan',
#   '1-0',
#   '2013.12.04',
#   '18:46:04',
#   '1511',
#   '1636',
#   'Italian Game: Two Knights Defense',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 Nc6 4. Bxf7+ Kxf7 5. Ng5+ Ke8 6. d4 g6 7. O-O exd4 8. Rfe1 Bc5 9. e5 Nd5 10. Qf3 Nxe5 11. Qxd5 d6 12. Rxe5+ dxe5 13. Qf7# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'redfanta87',
#   '1-0',
#   '2013.12.04',
#   '19:20:12',
#   '1526',
#   '1326',
#   'Pirc Defense #4',
#   '1. e4 d6 2. Bc4 Bd7 3. Nf3 Nf6 4. Bxf7+ Kxf7 5. Ng5+ Ke8 6. O-O h6 7. Nf3 d5 8. e5 Ng4 9. d4 Bb5 10. Rfe1 e6 11. h3 Nxf2 12. Kxf2 c5 13. Kg1 Nc6 14. Nfd2 Nxd4 15. Qh5+ Kd7 16. Na3 Qg5 17. Qf7+ Kc8 18. Ndc4 Qe7 19. Nd6+ Kd7 20. Qf2 Qd8 21. Ndxb5 Be7 22. Nxd4 Bh4 23. Qe2 Bxe1 24. Qb5+ Kc8 25. Qxc5+ Kd7 26. Qd6+ Ke8 27. Qxe6+ Qe7 28. Qg6+ Qf7 29. Qd3 Qf2+ 30. Kh1 Rhf8 31. Be3 Qf1+ 32. Qxf1 Rxf1+ 33. Bg1 Kd7 34. Nf3 Rxg1+ 35. Kxg1 Bg3 36. Rd1 Ke6 37. Nb5 Rc8 38. Nbd4+ Kf7 39. e6+ Kf6 40. c3 h5 41. Rd2 g5 42. Ne2 Bd6 43. Rxd5 Kxe6 44. Rxg5 Rd8 45. Rg6+ Kd7 46. Rh6 Ke7 47. Rh7+ Kf6 48. Rxh5 Kg6 49. Rg5+ Kf6 50. h4 b6 51. h5 a5 52. h6 Be7 53. h7 b5 54. Rg8 Rxg8 55. hxg8=Q 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'sirous-hosseinvand',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.04',
#   '19:39:42',
#   '1739',
#   '1532',
#   "Bishop's Opening: Calabrese Countergambit",
#   '1. e4 e5 2. Bc4 f5 3. exf5 Nf6 4. Nc3 c5 5. Nd5 a6 6. Nxf6+ Qxf6 7. Qh5+ g6 8. fxg6 hxg6 9. Qe2 Nc6 10. c3 d6 11. Nf3 Bg4 12. Qe4 Bf5 13. Qd5 O-O-O 14. d3 g5 15. Bxg5 Qg6 16. Bxd8 Nxd8 17. O-O Bh3 18. g3 Bxf1 19. Rxf1 Bh6 20. d4 e4 21. Nh4 Qh7 22. Nf5 Bf8 23. dxc5 Qxh2# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'sirous-hosseinvand',
#   '1-0',
#   '2013.12.04',
#   '19:53:39',
#   '1549',
#   '1722',
#   'Italian Game',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 Bd6 4. d4 exd4 5. Bxf7+ Kxf7 6. Ng5+ Kf8 7. O-O Nf6 8. f4 Be7 9. e5 Nd5 10. Qh5 g6 11. Qh6+ Ke8 12. Qg7 Rhf8 13. Nxh7 d6 14. Nxf8 Bxf8 15. Qxg6+ Kd7 16. e6+ Ke7 17. Qf7# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'sirous-hosseinvand',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.04',
#   '20:00:20',
#   '1705',
#   '1565',
#   'French Defense: La Bourdonnais Variation',
#   '1. f4 e6 2. e4 Qh4+ 3. g3 Qd8 4. Nf3 Bc5 5. d4 Bb6 6. Bd2 Ne7 7. Nc3 O-O 8. Bd3 f5 9. e5 d6 10. Qe2 dxe5 11. fxe5 Ba5 12. O-O-O a6 13. Ng5 h6 14. Nf3 b5 15. Kb1 Qd7 16. d5 b4 17. dxe6 Qe8 18. Ne4 fxe4 19. Bxe4 c6 20. Nh4 Bxe6 21. b3 Nd7 22. Qd3 Rac8 23. Bxh6 Nxe5 24. Bh7+ Kf7 25. Rhf1+ Nf5 26. Rxf5+ Bxf5 27. Qxf5+ Ke7 28. Qxe5+ Kf7 29. Qxg7+ Ke6 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'cosmarencos',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.04',
#   '20:14:31',
#   '1635',
#   '1558',
#   'Latvian Gambit: Mlotkowski Variation',
#   '1. e4 e5 2. Nf3 f5 3. Nc3 Nf6 4. d3 Be7 5. Nxe5 O-O 6. Bf4 d6 7. Nf3 fxe4 8. dxe4 Bg4 9. Be2 d5 10. exd5 Bb4 11. O-O Bxc3 12. bxc3 Ne4 13. c4 Rxf4 14. Nd4 Bxe2 15. Nxe2 Rff8 16. Qd4 Nf6 17. Nf4 c5 18. Qxc5 Na6 19. Qd4 Rac8 20. Ne6 Qe8 21. Nxf8 Qxf8 22. a3 Re8 23. Rab1 b6 24. d6 Re4 25. Qd3 Nc5 26. Qf3 Qxd6 27. Rbd1 Qc7 28. h4 Ng4 29. g3 Ne5 30. Qf5 Rxc4 31. Rd5 Ng6 32. Rfd1 Nf8 33. Rd5d8 Nce6 34. Qxe6+ Qf7 35. Rxf8+ Kxf8 36. Rd8+ 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'granagieldziePL',
#   '1-0',
#   '2013.12.04',
#   '20:32:02',
#   '1549',
#   '1553',
#   "Bishop's Opening",
#   '1. e4 e5 2. Bc4 Qh4 3. Nc3 c6 4. Nf3 Qf6 5. O-O g5 6. d4 exd4 7. e5 Qg6 8. Bd3 Qg7 9. Nxd4 g4 10. Nf5 Qg6 11. Nd6+ Kd8 12. Bxg6 hxg6 13. Nxf7+ Ke7 14. Nxh8 Bg7 15. Bg5+ Ke6 16. Qxg4+ Kxe5 17. Rfe1+ Kd6 18. Rad1+ Kc7 19. Bf4+ Kb6 20. Be3+ c5 21. Qxg6+ Bf6 22. Rd6+ Nc6 23. Qxg8 Be5 24. Qb3+ Kc7 25. Rxc6+ dxc6 26. Qf7+ Bd7 27. Bf4 Bxf4 28. Qxf4+ Kb6 29. a4 Rxh8 30. a5+ Kxa5 31. Qa4+ Kb6 32. Ne4 Kc7 33. Qxa7 Bf5 34. Nxc5 Bxc2 35. Qxb7+ Kd6 36. Qb4 Kc7 37. Ne6+ Kd7 38. Qd4+ Ke7 39. Nf4+ Kf7 40. Qxh8 c5 41. Qh5+ Kf6 42. Qg6+ Bxg6 43. Nxg6 Kxg6 44. Re6+ Kf5 45. Rc6 Kf4 46. Rxc5 Ke4 47. b4 Kd4 48. b5 Kxc5 49. b6 Kxb6 50. f4 Kc6 51. g4 Kd6 52. h4 Ke6 53. f5+ Kf6 54. Kg2 Ke5 55. Kg3 Kf6 56. Kf4 Kg7 57. g5 Kh7 58. h5 Kg7 59. Ke5 Kh7 60. Kf6 Kg8 61. h6 Kh7 62. Kf7 Kh8 63. f6 Kh7 64. g6+ Kh8 65. g7+ Kh7 66. g8=Q+ Kxh6 67. Qg6# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   't0522',
#   '1-0',
#   '2013.12.04',
#   '20:43:42',
#   '1561',
#   '1281',
#   'Caro-Kann Defense: Hillbilly Attack',
#   '1. e4 c6 2. Bc4 e6 3. Nf3 f6 4. e5 fxe5 5. Nxe5 Qf6 6. d4 Bd6 7. O-O Bxe5 8. dxe5 Qxe5 9. Rfe1 Qc5 10. Bb3 Nf6 11. Bg5 Ng8 12. Qh5+ g6 13. Qg4 h5 14. Qf4 Ne7 15. Nc3 Rhf8 16. Qd2 Rxf2 17. Qxf2 Qxf2+ 18. Kxf2 Nf5 19. h3 Nd4 20. Ne4 d5 21. Nd6+ Kd7 22. Nf7 b5 23. c3 Nf5 24. g4 Nd6 25. Nxd6 Kxd6 26. Bf4+ Ke7 27. gxh5 gxh5 28. Bg5+ Kf7 29. Ref1 Kg6 30. h4 a5 31. Bc2+ Kf7 32. Kg2+ Kg7 33. Rae1 Bd7 34. Rf2 Na6 35. Ref1 Nc5 36. Rf2f7+ Kg8 37. Bh7+ Kh8 38. Bf6# 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'suryavan',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.04',
#   '20:52:38',
#   '1742',
#   '1565',
#   'Latvian Gambit',
#   '1. e4 e5 2. Nf3 f5 3. Nxe5 Nf6 4. exf5 d6 5. Nf3 Be7 6. Bc4 d5 7. Bb5+ c6 8. Bd3 O-O 9. O-O c5 10. Nc3 c4 11. Be2 Bxf5 12. Nd4 Bd7 13. Bf3 Nc6 14. Nxc6 Bxc6 15. Rfe1 Qd7 16. Ne2 Rae8 17. Nd4 b5 18. Re2 Bc5 19. Nxc6 Qxc6 20. d4 Bd6 21. Be3 Qc7 22. h3 a5 23. c3 b4 24. Qc2 Bf4 25. Rae1 Bxe3 26. Re2xe3 Qb8 27. Qf5 Red8 28. Re3e5 bxc3 29. bxc3 Ne4 30. Qe6+ Kh8 31. Bxe4 dxe4 32. Re5xe4 Qc7 33. Qg4 Qb6 34. Re4e7 Rfg8 35. Qe6 Qb5 36. Qe2 Rdf8 37. Re7e5 Qa4 38. Rc5 Rfe8 39. Qd2 Rxe1+ 40. Qxe1 Qxa2 41. Rxc4 Qxc4 42. Qe8 Rxe8 0-1\n'],
#  ['Rated Bullet game',
#   'Time forfeit',
#   'ASTROSCEPTRE',
#   'Mein_Kampf',
#   '0-1',
#   '2013.12.04',
#   '21:16:48',
#   '1152',
#   '1524',
#   'Modern Defense',
#   '1. e4 g6 2. Bc4 Bg7 3. Bxf7+ Kxf7 4. Nf3 Ke8 5. Ng5 Nf6 6. Qf3 Rhf8 7. O-O Nh5 8. Qb3 Bf6 9. d4 Bxg5 10. Bxg5 Nf6 11. e5 Ne4 12. Na3 Nxg5 13. Rae1 d6 14. f4 Ne6 15. Qg3 dxe5 16. Qh4 Nxf4 17. Qxh7 Rf7 18. Qh6 Bf5 19. g3 Nh5 20. Rxf5 gxf5 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'el_peon_cito',
#   '0-1',
#   '2013.12.04',
#   '21:18:46',
#   '1382',
#   '1509',
#   'Sicilian Defense: Bowdler Attack',
#   '1. e4 c5 2. Bc4 e6 3. Nf3 Nc6 4. O-O Nf6 5. d3 d5 6. exd5 exd5 7. Bb5 Be7 8. Ng5 O-O 9. f4 Nd7 10. Qh5 Bxg5 11. fxg5 Nd4 12. Na3 Ne5 13. Bf4 Ng6 14. c3 Nxb5 15. Nxb5 a6 16. Na3 Qb6 17. Qe2 c4+ 18. Kh1 cxd3 19. Qxd3 Qxb2 20. Nc2 Bd7 21. Nd4 Nxf4 22. Qf3 Ne6 23. Nxe6 Bxe6 24. g6 fxg6 0-1\n'],
#  ['Rated Classical game',
#   'Time forfeit',
#   'ASTROSCEPTRE',
#   'pedege',
#   '1-0',
#   '2013.12.04',
#   '21:25:10',
#   '1581',
#   '1660',
#   'Italian Game: Anti-Fried Liver Defense',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 h6 4. d4 exd4 5. a3 Bc5 6. O-O d6 7. b4 Bb6 8. b5 Na5 9. Ba2 Be6 10. Bxe6 fxe6 11. e5 d5 12. Nfd2 g6 13. Qg4 Kf7 14. Kh1 h5 15. Qf3+ Kg7 16. Nb3 Nc4 17. Qh3 Qd7 18. Bg5 Raf8 19. f4 Nxe5 20. Nb1d2 Ng4 21. Rae1 Ng8f6 22. Qf3 a6 23. Qd3 Ne4 24. Nxe4 dxe4 25. Qxe4 e5 26. h3 Rfe8 27. f5 gxf5 28. Rxf5 d3 29. Be3 Bxe3 30. Rxe3 dxc2 31. Rg5+ Kf8 32. Rf3+ Ke7 33. Qxc2 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'rsiemon',
#   '0-1',
#   '2013.12.04',
#   '21:48:14',
#   '1374',
#   '1474',
#   'Italian Game: Rosentreter Gambit',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 Bc5 4. d4 Bxd4 5. Bxf7+ Kxf7 6. Ng5+ Kf8 7. c3 Bb6 8. Qf3+ Qf6 9. Qd1 h6 10. Nf3 d6 11. O-O Bg4 12. Nbd2 Nge7 13. h3 Bh5 14. g4 Bg6 15. b4 a6 16. Nc4 Bxe4 17. Kg2 Bxf3+ 18. Qxf3 Qxf3+ 19. Kxf3 Ng6 20. Nxb6 cxb6 21. Be3 b5 22. Bb6 Ke7 23. Rad1 Nb8 24. Bc7 Nc6 25. Bxd6+ Ke6 26. Bc5 Rhd8 27. Rde1 Rd3+ 28. Kg2 Rxc3 29. f4 Rc2+ 30. Kg3 Kd7 31. Red1+ Ke8 32. f5 Nge7 33. Kh4 Rc3 34. g5 Rc4+ 35. Kh5 hxg5 36. Kxg5 Rd8 37. h4 Rxd1 38. Rxd1 Nd4 39. h5 Ndxf5 40. h6 gxh6+ 41. Kh5 Rh4# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'rub',
#   '1-0',
#   '2013.12.04',
#   '21:58:30',
#   '1595',
#   '1682',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 d6 4. Bxf7+ Kxf7 5. Ng5+ Ke7 6. O-O Nxe4 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'rub',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.04',
#   '22:00:12',
#   '1667',
#   '1609',
#   "King's Pawn Game: Busch-Gass Gambit",
#   '1. e4 e5 2. Nf3 Bc5 3. Nc3 Nf6 4. d3 Bxf2+ 5. Kxf2 Ng4+ 6. Ke2 d6 7. h3 Nf6 8. Be3 O-O 9. Qd2 d5 10. Bg5 d4 11. Bxf6 Qxf6 12. Nd5 Qa6 13. Nxc7 Qg6 14. Nxa8 f5 15. Nxe5 Qh5+ 16. Ke1 Qh4+ 17. g3 Qxg3+ 18. Qf2 Qxe5 19. Qg2 fxe4 20. dxe4 Qa5+ 21. Qd2 Qg5 22. Qxg5 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'rub',
#   '0-1',
#   '2013.12.04',
#   '22:06:49',
#   '1599',
#   '1677',
#   'Russian Game: Urusov Gambit',
# ...
#  ['Rated Classical game',
#   'Normal',
#   'segap65',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.20',
#   '20:03:00',
#   '1561',
#   '1566',
#   'Sicilian Defense: Old Sicilian',
#   '1. e4 c5 2. Nf3 Nc6 3. Nc3 e5 4. a3 Nf6 5. Bb5 Be7 6. Bxc6 bxc6 7. d3 Qa5 8. Bd2 Qd8 9. O-O d5 10. Nxe5 d4 11. Na4 O-O 12. Nxc6 Qc7 13. Na5 Bd6 14. g3 Ng4 15. Qf3 f5 16. Bf4 Bxf4 17. exf5 Nxh2 18. Qxf4 Qxa5 19. b3 Rxf5 20. Qh4 Nxf1 21. Rxf1 Bd7 22. Qe4 Re8 23. Qg4 Rxf2 24. Qxd7 Rxf1+ 25. Kxf1 Qe1+ 26. Kg2 Re2+ 27. Kh3 Qh1+ 28. Kg4 h5+ 29. Kf4 Qf1+ 30. Kg5 Re5+ 31. Kh4 Qh1+ 32. Qh3 Qxh3+ 33. Kxh3 Re2 34. Nxc5 Rxc2 35. Ne6 g6 36. Nxd4 Rc3 37. Nb5 Rxd3 38. Nxa7 Rxb3 39. Nc6 Rxa3 40. Ne5 Kg7 41. Kh4 Ra4+ 42. Kg5 Ra5 43. Kf4 Kf6 44. Nf3 Rf5+ 45. Ke4 g5 46. Nd4 Re5+ 47. Kf3 g4+ 48. Kf4 Re1 49. Nf5 Rf1+ 50. Ke4 Rxf5 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'sebastian1212',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.20',
#   '20:19:22',
#   '1700',
#   '1577',
#   'Sicilian Defense: Old Sicilian',
#   '1. e4 c5 2. Nf3 Nc6 3. c3 e5 4. Bb5 Nf6 5. d3 a6 6. Bxc6 bxc6 7. Nxe5 Qc7 8. Nf3 Be7 9. O-O O-O 10. Bg5 d6 11. Qe1 Ng4 12. h3 Ne5 13. Bxe7 Nxf3+ 14. gxf3 Qxe7 15. Kh1 Bxh3 16. Rfg1 Qh4 17. Qe3 Be6+ 18. Kg2 Qh3# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'sagenwald',
#   '0-1',
#   '2013.12.20',
#   '20:41:02',
#   '1591',
#   '1709',
#   'Philidor Defense #3',
#   '1. e4 e5 2. Bc4 d6 3. Nf3 g6 4. d4 h6 5. dxe5 Bg4 6. Qd3 Bxf3 7. Bxf7+ Kxf7 8. Qxf3+ Kg7 9. e6 Qe7 10. O-O Qxe6 11. Qc3+ Kh7 12. Qxc7+ Qd7 13. Qc3 Bg7 14. Qg3 Nf6 15. e5 dxe5 16. f4 Nc6 17. Nc3 Rhf8 18. f5 gxf5 19. Bd2 Nd4 20. Rad1 Rad8 21. Qxe5 Ne4 22. Nxe4 Bxe5 23. Nf6+ Rxf6 24. Bc3 Ne2+ 25. Kh1 Qxd1 26. Rxd1 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'zanganeh',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.21',
#   '13:42:00',
#   '1302',
#   '1470',
#   'Hungarian Opening: Sicilian Invitation',
#   '1. g3 c5 2. c4 Nc6 3. Bg2 e5 4. e4 Nf6 5. d3 Be7 6. Ne2 O-O 7. O-O d5 8. cxd5 Nd4 9. Nxd4 cxd4 10. f4 Ng4 11. fxe5 Ne3 12. Bxe3 dxe3 13. Rfe1 Bc5 14. d4 Bb6 15. Rxe3 f5 16. Na3 f4 17. gxf4 Qh4 18. Qb3 Kh8 19. Nb5 a6 20. Nd6 Bxd4 21. Nxc8 Bxe3+ 22. Qxe3 Raxc8 23. e6 Rxf4 24. Bh3 Qg5+ 25. Kh1 Rf1+ 26. Bxf1 Qxe3 27. e7 Qxe4+ 28. Bg2 Qxe7 29. Rd1 Rc2 30. Bf3 Qd6 31. a3 Qxh2# 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'Ashbytom',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.21',
#   '13:52:59',
#   '1864',
#   '1583',
#   'Sicilian Defense: Closed Variation, Fianchetto Variation',
#   '1. e4 c5 2. Nc3 Nc6 3. g3 e5 4. Bg2 Nf6 5. d3 Be7 6. Nge2 O-O 7. Be3 d5 8. exd5 Nd4 9. Qd2 Ng4 10. O-O f5 11. f4 exf4 12. Bxf4 Nxe2+ 13. Qxe2 c4 14. dxc4 Bc5+ 15. Kh1 Rfe8 16. Qf3 Ne3 17. Bxe3 Bxe3 18. Qh5 f4 19. gxf4 Ref8 20. f5 Qb6 21. b3 Bd4 22. Rf3 Qa5 23. Rh3 h6 24. Rf1 Bxc3 25. Be4 Qxa2 26. Rg3 Be5 27. Rg6 b5 28. Qxh6 Qb2 29. Rfg1 Kf7 30. Qh5 Ke7 31. Re6+ Bxe6 32. fxe6 Qd4 33. Qh4+ Bf6 34. Rxg7+ Kd6 35. Rd7+ Kc5 36. Qg3 Qxe4+ 37. Kg1 Bd4+ 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'aidarhan',
#   '0-1',
#   '2013.12.21',
#   '14:12:35',
#   '1477',
#   '1755',
#   'Caro-Kann Defense: Hillbilly Attack',
#   '1. e4 c6 2. Bc4 d5 3. exd5 cxd5 4. Bd3 e5 5. Bb5+ Bd7 6. Qe2 e4 7. Bxd7+ Qxd7 8. Nh3 Nc6 9. O-O Nd4 10. Qd1 Nf3+ 11. Kh1 Bd6 12. d3 Nxh2 13. Rfg1 Ng4 14. dxe4 Ng8f6 15. Bf4 Bxf4 16. Nxf4 Nxf2+ 17. Kh2 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'emperator',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '14:17:00',
#   '1684',
#   '1473',
#   'Old Benoni Defense',
#   '1. d4 c5 2. e3 Nc6 3. d5 Ne5 4. c4 Qa5+ 5. Bd2 Qc7 6. f4 Ng6 7. Nf3 e5 8. f5 Ng6e7 9. e4 d6 10. Be2 Nf6 11. Nc3 Ng4 12. h3 Nf6 13. g4 b5 14. b3 bxc4 15. Bxc4 g6 16. g5 gxf5 17. gxf6 Ng6 18. Nb5 Qb6 19. exf5 Bxf5 20. Rhg1 e4 21. Ng5 Bh6 22. Qh5 Bxg5 23. Qxg5 Bxh3 24. Qg3 Bd7 25. Nxd6+ Kd8 26. O-O-O a5 27. Nxf7+ Ke8 28. Nxh8 a4 29. f7+ Kf8 30. Bh6+ 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'olenchuk',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '14:22:25',
#   '1713',
#   '1601',
#   'Sicilian Defense: Loewenthal Variation',
#   '1. e4 c5 2. Nf3 Nc6 3. d4 cxd4 4. Nxd4 e5 5. Nxc6 bxc6 6. Bc4 Nf6 7. Nc3 Bb4 8. Bd2 O-O 9. O-O d5 10. exd5 cxd5 11. Nxd5 Nxd5 12. Bxd5 Rab8 13. Bxb4 Rxb4 14. Bb3 Qh4 15. c3 Rg4 16. Qf3 e4 17. Qe3 Kh8 18. Bd1 Rg6 19. Be2 Rh6 20. h3 f5 21. f4 exf3 22. Rxf3 Re6 23. Qf2 Qxf2+ 24. Rxf2 f4 25. Bf3 Re7 26. Rd1 Bb7 27. Bxb7 Rxb7 28. b3 f3 29. Rxf3 Kg8 30. Rxf8+ Kxf8 31. Rd2 Re7 32. Kf1 Rf7+ 33. Rf2 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'gurzo2013',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '15:01:00',
#   '1667',
#   '1594',
#   'Benoni Defense: Benoni-Indian Defense',
#   '1. d4 c5 2. d5 Nf6 3. c4 Qa5+ 4. Bd2 Qb6 5. Qc2 e6 6. e4 Bd6 7. f4 Be7 8. e5 Ng4 9. d6 Bh4+ 10. g3 Bd8 11. Be2 Nh6 12. Nf3 Nf5 13. O-O Nd4 14. Nxd4 cxd4 15. Bd3 O-O 16. Bxh7+ Kh8 17. Bd3 Nc6 18. a3 Na5 19. b4 Nxc4 20. Qxc4 a5 21. b5 a4 22. Bb4 Qa7 23. Nd2 f6 24. Nf3 fxe5 25. Nxe5 Bf6 26. Ng6+ Kg8 27. Nxf8 Kxf8 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'sagenwald',
#   '0-1',
#   '2013.12.21',
#   '15:53:17',
#   '1585',
#   '1695',
#   'Philidor Defense #3',
#   '1. e4 e5 2. Bc4 d6 3. Nf3 g6 4. d4 exd4 5. Bxf7+ Kxf7 6. Ng5+ Kg7 7. Qf3 Qf6 8. Qb3 h6 9. e5 Qxe5+ 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'Shamarin69',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '15:55:28',
#   '1689',
#   '1577',
#   'Sicilian Defense',
#   '1. e4 c5 2. Qh5 Nc6 3. Bc4 e6 4. c3 Qa5 5. b4 cxb4 6. Qxa5 Nxa5 7. Bb5 a6 8. cxb4 axb5 9. bxa5 Rxa5 10. d3 Nf6 11. Bd2 Raa8 12. Nc3 b4 13. Nb5 Ra7 14. Nxa7 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'jonafib',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '16:01:30',
#   '1635',
#   '1467',
#   'Sicilian Defense: Old Sicilian',
#   '1. e4 c5 2. Nf3 Nc6 3. c3 Qa5 4. d3 e5 5. Bd2 b5 6. a4 Nf6 7. Be2 d5 8. exd5 Nxd5 9. O-O Be7 10. c4 Ndb4 11. cxb5 Nd4 12. Nxe5 O-O 13. Nc4 Qd8 14. Bc3 Bb7 15. Nbd2 Bh4 16. g3 Qd5 17. Ne4 Bd8 18. Bxd4 cxd4 19. Bf3 f5 20. Nf6+ Rxf6 21. Bxd5+ Bxd5 22. Qd2 Be7 23. b6 axb6 24. Ne5 f4 25. Nd7 Rd6 26. Qxb4 Rxd7 27. Qxb6 fxg3 28. fxg3 Rb7 29. Qxd4 Bf7 30. Rae1 Rc8 31. Qg4 Bc5+ 32. d4 Bxd4+ 33. Qxd4 Rxb2 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'schoebbes',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '16:11:10',
#   '1483',
#   '1570',
#   'Sicilian Defense: McDonnell Attack',
#   '1. e4 c5 2. f4 Nc6 3. e5 e6 4. Nf3 d6 5. exd6 Nd4 6. Nc3 Bxd6 7. Ne4 Bxf4 8. Nxc5 Nxf3+ 9. Qxf3 Qh4+ 10. g3 Bxg3+ 11. hxg3 Qb4 12. Qc3 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'frantaIQ',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '16:16:11',
#   '1657',
#   '1556',
#   'Sicilian Defense: Bowdler Attack',
#   '1. e4 c5 2. Bc4 Nc6 3. Nc3 e5 4. Nd5 Nf6 5. Nc3 d5 6. exd5 Nd4 7. d3 Ng4 8. Nh3 Bd6 9. Bg5 f6 10. Bh4 O-O 11. Qd2 Nh6 12. O-O-O a6 13. g3 b5 14. g4 bxc4 15. g5 Bxh3 16. gxh6 Nf3 17. Qe3 e4 18. hxg7 Rf7 19. Nxe4 Bg2 20. Bg3 Bxh1 21. Rxh1 Bxg3 22. hxg3 Ne5 23. Qh6 Rxg7 24. Nxf6+ Kf7 25. Nxh7 Ng6 26. Ng5+ Kg8 27. f4 cxd3 28. f5 d2+ 29. Kd1 Qxd5 30. fxg6 Qxh1+ 31. Qxh1 Re8 32. Qd5+ Kh8 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'hankm00dy',
#   '1-0',
#   '2013.12.21',
#   '17:14:37',
#   '1461',
#   '1408',
#   "Bishop's Opening: Boi Variation",
#   '1. e4 e5 2. Bc4 Bc5 3. Nf3 d6 4. d4 exd4 5. Ng5 Be6 6. Bxe6 fxe6 7. Nxe6 Qe7 8. Nxc5 dxc5 9. O-O Nf6 10. e5 Nd5 11. Qh5+ g6 12. Qg4 O-O 13. e6 Nc6 14. Bh6 Rf4 15. Bxf4 Nxf4 16. Qxf4 Qxe6 17. Nd2 Re8 18. Rae1 Qxe1 19. Rxe1 Rxe1+ 20. Nf1 Ne7 21. Qxc7 Nf5 22. Qxb7 Nd6 23. Qd5+ 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'hankm00dy',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '17:19:33',
#   '1398',
#   '1471',
#   'Sicilian Defense: Bowdler Attack',
#   '1. e4 c5 2. Bc4 Nc6 3. Qf3 e5 4. Qxf7# 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'hankm00dy',
#   '0-1',
#   '2013.12.21',
#   '17:20:15',
#   '1457',
#   '1412',
#   "Bishop's Opening: Boi Variation",
#   '1. e4 e5 2. Bc4 Bc5 3. Nf3 Nf6 4. Bxf7+ Kxf7 5. Nxe5+ Ke7 6. d4 Bb4+ 7. c3 Ba5 8. b4 Bb6 9. Bg5 d6 10. Ng4 Kf7 11. O-O Bxg4 12. f3 Bh5 13. Qb3+ Ke8 14. e5 Bf7 15. exf6 Bxb3 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'hankm00dy',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '17:25:19',
#   '1426',
#   '1444',
#   'Sicilian Defense: Bowdler Attack',
#   '1. e4 c5 2. Bc4 Nc6 3. Qf3 e6 4. Nc3 Nd4 5. Qd3 e5 6. Nf3 Nf6 7. Nxe5 Ne6 8. Nd5 Bd6 9. Nxf6+ Qxf6 10. Ng4 Qh4 11. h3 O-O 12. e5 Nf4 13. Qf3 Rfe8 14. O-O Bxe5 15. Nxe5 Rxe5 16. d3 d5 17. Bxf4 Rf5 18. g3 Qxh3 19. Bxd5 Rh5 20. Qg2 Qf5 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'Joanot-Martorell',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.21',
#   '18:03:33',
#   '1396',
#   '1432',
#   'Benoni Defense: Benoni Gambit Accepted',
#   '1. d4 c5 2. dxc5 Nc6 3. Nf3 e5 4. Qd5 Nf6 5. Nxe5 Nxd5 6. Nxc6 bxc6 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'temp500',
#   '0-1',
#   '2013.12.21',
#   '18:07:37',
#   '1548',
#   '1643',
#   'Giuoco Piano',
#   '1. e4 e5 2. Bc4 Nc6 3. Nf3 Bc5 4. O-O d6 5. d4 exd4 6. Ng5 Nh6 7. Nxf7 Nxf7 8. Bxf7+ Kxf7 9. Qh5+ g6 10. Qf3+ Qf6 11. Qb3+ Kf8 12. f4 d3+ 13. Kh1 dxc2 14. Qxc2 Nd4 15. Qd2 Kg7 16. Nc3 c6 17. e5 dxe5 18. a3 Bf5 19. b4 Bb6 20. Bb2 Nb3 21. Qe2 Nxa1 22. Rxa1 Rhe8 23. Ne4 Bxe4 24. Qxe4 Bd4 25. fxe5 Bxe5 26. Bxe5 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'romena',
#   '1-0',
#   '2013.12.21',
#   '18:20:30',
#   '1540',
#   '1450',
#   'Borg Defense',
#   '1. e4 g5 2. Bc4 Nc6 3. Bxf7+ Kxf7 4. Qh5+ Kf6 5. b3 e5 6. Nf3 d6 7. Qxg5+ Ke6 8. Qg4+ Ke7 9. Qg3 h6 10. d4 Bg7 11. Bb2 exd4 12. O-O Be6 13. Qxg7+ Bf7 14. Qxh8 Kd7 15. Nxd4 Nxd4 16. Bxd4 Kc8 17. Qg7 Bh5 18. f4 b6 19. e5 dxe5 20. Bxe5 Ne7 21. Nc3 Nf5 22. Rad1 Nxg7 23. Rxd8+ Kxd8 24. Bxg7 Be8 25. Bxh6 Kc8 26. f5 Kb7 27. f6 Bf7 28. Ne4 Re8 29. Ng5 Bd5 30. f7 Bxf7 31. Nxf7 Re2 32. Nd8+ Ka6 33. Rc1 b5 34. c4 Kb6 35. c5+ Ka6 36. Bf4 Rxa2 37. Bxc7 b4 38. Be5 Ra5 39. Ra1 Kb5 40. Rxa5+ Kxa5 41. g4 Kb5 42. Bd6 a6 43. g5 a5 44. g6 a4 45. g7 axb3 46. g8=Q b2 47. Qe8+ Ka5 48. Qe1 Ka4 49. Be5 Ka3 50. Qb1 b3 51. Qxb2+ Kb4 52. c6 Kc5 53. c7 Kb4 54. c8=Q Ka4 55. h4 Kb4 56. h5 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'parranda',
#   '0-1',
#   '2013.12.21',
#   '19:02:54',
#   '1549',
#   '1486',
#   'Russian Game: Urusov Gambit',
#   '1. e4 e5 2. Bc4 Nf6 3. Nf3 d6 4. Bxf7+ Kxf7 5. Ng5+ Ke8 6. O-O h6 7. Nf3 Be7 8. d4 Kf7 9. dxe5 Nh7 10. Nd4 Rhf8 11. Qh5+ Kg8 12. Nf5 Bxf5 13. exf5 Bg5 14. f4 Rxf5 15. e6 Qf6 16. Qe8+ Nf8 17. e7 Qxe7 18. Qa4 Bf6 19. Nc3 Bxc3 20. Qc4+ Kh8 21. Qxc3 Ne6 22. Be3 Nc6 23. Rae1 Re8 24. b4 a6 25. a4 Qf7 26. b5 Ne7 27. bxa6 Nd5 28. Qd3 Nxe3 29. Rxe3 Rxf4 30. Rxf4 Nxf4 31. Rxe8+ Qxe8 32. Qf3 Ne2+ 33. Kf2 Nd4 34. Qxb7 Qe2+ 35. Kg3 Nf5+ 36. Kf4 Qf2+ 37. Ke4 Qxg2+ 38. Kxf5 Qf2+ 39. Ke6 Qf6+ 40. Kd7 Qf7+ 41. Kc6 Qe8+ 42. Kxc7 Qe7+ 43. Kc6 Qe8+ 44. Kb6 Qe3+ 45. Ka5 Qc5+ 46. Qb5 Qc7+ 47. Kb4 Qa7 48. Qb7 Qc5+ 49. Kb3 Qe3+ 50. Kb2 Qe5+ 51. Kb3 Qe3+ 52. Kc4 Qe6+ 53. Qd5 Qc8+ 54. Kd4 Qxa6 55. c4 Qxa4 56. Qxd6 Qd1+ 57. Kc5 Qg1+ 58. Kc6 Qc1 59. Qf8+ Kh7 60. Qf5+ Kh8 61. Qf8+ Kh7 62. Qf5+ Kg8 63. Qe6+ Kf8 64. Qf5+ Ke7 65. Qe4+ Kf6 66. Qd4+ Kg6 67. Qg4+ Kh7 68. Qf5+ Kh8 69. Qf8+ Kh7 70. Qf5+ Kh8 71. Qf8+ Kh7 72. Qf5+ Kg8 73. Qe6+ Kf8 74. Qf5+ Ke7 75. Qg6 Qxc4+ 76. Kb7 Qd5+ 77. Kb6 Qd6+ 78. Qxd6+ Kxd6 0-1\n'],
#  ['Rated Classical game',
#   'Time forfeit',
#   'Sommer2130',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.21',
#   '20:03:37',
#   '1569',
#   '1536',
#   'Sicilian Defense: Bowdler Attack',
#   '1. e4 c5 2. Bc4 Nc6 3. Qh5 e6 4. Nf3 a6 5. Ne5 Nxe5 6. Qxe5 b5 7. Be2 Nf6 8. d3 Be7 9. Bg5 O-O 10. Bf4 d6 11. Qc3 b4 12. Qd2 e5 13. Bg5 Ng4 14. Bxe7 Qxe7 15. Bxg4 Bxg4 16. h3 Bh5 17. g4 Bg6 18. h4 f5 19. h5 Bf7 20. g5 fxe4 21. dxe4 Bc4 22. Qe3 Rf4 23. Nd2 Bb5 24. c4 Bc6 25. f3 Qxg5 26. O-O-O a5 27. Rdg1 Qf6 28. Rg4 a4 29. Rxf4 Qxf4 30. Qxf4 exf4 31. Rd1 a3 32. b3 Re8 33. Nf1 Re6 34. Nh2 Rh6 35. Ng4 Rxh5 36. Rxd6 Rh1+ 37. Kc2 Be8 38. Ne5 Rh2+ 39. Kb1 Rh1+ 40. Kc2 Rh2+ 41. Kd3 Rxa2 42. Rd8 Kf8 43. Nd7+ Ke7 44. Rc8 Bxd7 45. Rxc5 Ra1 46. Rb5 a2 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'misha-prokopets-2003',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.21',
#   '20:26:48',
#   '1483',
#   '1548',
#   'Sicilian Defense: Smith-Morra Gambit #2',
#   '1. e4 c5 2. d4 cxd4 3. Qxd4 Nc6 4. Qd1 e5 5. Nc3 Nf6 6. Bg5 Be7 7. Bxf6 Bxf6 8. Nd5 O-O 9. Nxf6+ Qxf6 10. Qd5 Nb4 11. Qc4 a5 12. a3 d5 13. exd5 b5 14. Qxb5 Nxc2+ 15. Kd1 Qxf2 16. Nf3 Ne3+ 17. Kc1 Qc2# 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'nebojsa',
#   '0-1',
#   '2013.12.21',
#   '20:46:26',
#   '1442',
#   '1595',
#   'Scandinavian Defense: Modern Variation #2',
#   '1. e4 d5 2. exd5 Nf6 3. Bc4 Nxd5 4. Nf3 e6 5. Ne5 Bc5 6. Nxf7 Kxf7 7. Qf3+ Qf6 8. Qh5+ g6 9. Qe2 Nf4 10. Bxe6+ Qxe6 11. Qxe6+ Nxe6 12. O-O Rhf8 13. c3 Kg7 14. d4 Bd6 15. Na3 a6 16. d5 Nf4 17. g3 Nd3 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'KRALL08',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '20:49:37',
#   '1346',
#   '1436',
#   'Zukertort Opening: Sicilian Invitation',
#   '1. Nf3 c5 2. d4 cxd4 3. Nxd4 Nc6 4. Nxc6 bxc6 5. e3 Qa5+ 6. Nc3 e5 7. Be2 Nf6 8. O-O Bb4 9. Bd2 O-O 10. a3 Bxc3 11. Bxc3 Qc7 12. b4 d5 13. h3 Ne4 14. Bb2 f5 15. Rab1 f4 16. exf4 Bxh3 17. gxh3 exf4 18. Bf3 Qe5 19. Bxe5 1-0\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'chemin',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.21',
#   '20:56:15',
#   '1410',
#   '1422',
#   'Sicilian Defense',
#   '1. e4 c5 2. Qh5 Nc6 3. Qxc5 e5 4. d3 Bxc5 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'ASTROSCEPTRE',
#   'sagenwald',
#   '0-1',
#   '2013.12.21',
#   '21:16:00',
#   '1556',
#   '1713',
#   "Bishop's Opening",
#   '1. e4 e5 2. Bc4 g6 3. f4 Bg7 4. Nf3 exf4 5. O-O h6 6. e5 Ne7 7. d4 O-O 8. Bxf4 d6 9. Qd2 Nbc6 10. Bxh6 dxe5 11. Bxg7 Kxg7 12. Qg5 Nf5 13. Qxd8 Rfxd8 14. dxe5 Nb4 15. Na3 Ne3 16. Rfc1 Bf5 17. Bd3 Nxd3 18. cxd3 c6 19. Rce1 Rxd3 20. Ng5 Re8 21. Nf3 Bg4 22. Kf2 Bxf3 23. Rxe3 Rdxe3 24. Kxe3 Bxg2 25. Kf2 Bd5 26. Re1 Kh6 27. Nc2 Bxa2 28. Nd4 Bd5 29. b4 Kg5 30. Kg3 Rh8 31. Rf1 Rh4 32. Nf3+ Bxf3 33. Rxf3 Rg4+ 34. Kh3 Rf4 35. Re3 Rxb4 36. e6 fxe6 37. Rxe6 Kf5 38. Re7 0-1\n'],
#  ['Rated Classical game',
#   'Normal',
#   'sagenwald',
#   'ASTROSCEPTRE',
#   '0-1',
#   '2013.12.21',
#   '21:30:38',
#   '1719',
#   '1550',
#   'Benoni Defense: Benoni Gambit Accepted',
#   '1. d4 c5 2. dxc5 Nc6 3. e3 Qa5+ 4. Nc3 Qxc5 5. g3 e5 6. Bg2 Nf6 7. Nf3 Be7 8. O-O O-O 9. e4 Nd4 10. Be3 d5 11. Bxd4 exd4 12. exd5 dxc3 13. Rfe1 Bd6 14. bxc3 Bg4 15. Rab1 b5 16. Qd3 Bxf3 17. Bxf3 Qa3 18. Qxb5 Qxc3 19. Re2 Qxf3 0-1\n'],
#  ['Rated Blitz game',
#   'Normal',
#   'milentije',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '21:47:51',
#   '1604',
#   '1433',
#   'Sicilian Defense: Open #3',
#   '1. e4 c5 2. Nf3 Nc6 3. d4 cxd4 4. Nxd4 Qa5+ 5. Nc3 e5 6. Nxc6 bxc6 7. Bc4 Nf6 8. O-O Be7 9. f4 Bc5+ 10. Kh1 exf4 11. Bxf4 O-O 12. e5 Nd5 13. Nxd5 cxd5 14. Qxd5 Rab8 15. b3 Bb7 16. Qd3 d5 17. Bxd5 Rfd8 18. c4 Bxd5 19. cxd5 Bb4 20. e6 fxe6 21. Bxb8 Rxd5 22. Qc4 Be7 23. Rac1 Rd8 24. Qxe6+ Kh8 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'sova77',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '22:16:10',
#   '1686',
#   '1566',
#   'Mieses Opening',
#   '1. d3 c5 2. e3 Nc6 3. Nc3 e5 4. a3 d5 5. Be2 Nf6 6. Bd2 Be7 7. e4 d4 8. Na2 O-O 9. Nf3 Ng4 10. h3 Nf6 11. c3 dxc3 12. Bxc3 Nd4 13. Nxe5 Nd7 14. Nf3 Nxf3+ 15. Bxf3 f5 16. O-O Nb6 17. a4 c4 18. d4 fxe4 19. Bxe4 Bd6 20. Bf3 Bxh3 21. gxh3 Qh4 22. Bg2 Qf4 23. Rfe1 Qh2+ 24. Kf1 Bg3 25. Re2 Rae8 26. Be1 Nd5 27. Rxe8 Rxe8 28. Qf3 Ne3+ 29. fxe3 Rf8 30. Qxf8+ Kxf8 31. Bxg3 Qxg3 32. Re1 Qd6 33. Re2 b6 34. Nc3 Qb4 35. e4 b5 36. axb5 Qa5 37. d5 Qd8 38. e5 Qh4 39. e6 Ke7 40. Rf2 Qd4 41. Rf7+ Ke8 42. Rd7 Qd3+ 43. Kg1 Qc2 44. d6 Qc1+ 45. Kh2 Qxb2 46. Rxa7 Qxc3 47. Ra8# 1-0\n'],
#  ['Rated Bullet game',
#   'Normal',
#   'beatable',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.21',
#   '22:32:00',
#   '1572',
#   '1195',
#   'Sicilian Defense: Alapin Variation',
#   '1. e4 c5 2. c3 Nc6 3. d4 cxd4 4. cxd4 d5 5. exd5 Nb8 6. Nc3 Nf6 7. Bc4 Qa5 8. Bd2 b5 9. Nxb5 Qb6 10. Bf4 a6 11. Nc7+ 1-0\n'],
#  ['Rated Classical game',
#   'Normal',
#   'Josef13',
#   'ASTROSCEPTRE',
#   '1-0',
#   '2013.12.24',
#   '16:24:51',
#   '1443',
#   '1559',
#   'Sicilian Defense: Bowdler Attack',
#   '1. e4 c5 2. Bc4 Nc6 3. Nf3 e5 4. Nc3 Nf6 5. O-O a6 6. a3 b5 7. Ba2 c4 8. h3 Bc5 9. d3 O-O 10. dxc4 bxc4 11. b4 Bb6 12. Qe2 d5 13. Bg5 d4 14. Nd5 Qc7 15. Nxc7 1-0\n']]

# %%
len(dict_career_MAIN.keys())
# Out:
# 73575

# %%
len(dict_career.keys())
# Out:
# 37326

# %%
# how_many_=0
# for key_ in dict_career.keys():
#     how_many_=how_many_+int(key_ in dict_career_MAIN.keys())
# how_many_
