# %%
import time
import pandas as pd
import glob
import numpy as np
import timeit
import pickle

from multiprocessing import Pool
from matplotlib import pyplot as plt
def toc(start_time):
    elapsed = timeit.default_timer() - start_time
    print(elapsed)
start_time = timeit.default_timer()

# import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})
#matplotlib.rcParams.update({'font.size': 18})

path_dicts='/mnt/sdb1/sandeep/dicts_chess/'

# %%
t_ic=time.time()

YEAR_OF_PGN=2013

file_to_read = open(path_dicts+"dict_merged_"+str(YEAR_OF_PGN)+".pkl", "rb")
dict_career_MAIN= pickle.load(file_to_read)

t_oc=time.time();
print(t_oc-t_ic,' seconds')
# Out:
# 18.260660648345947  seconds

# %%
# store_keys=[]
# for key_ in dict_career_MAIN.keys():
#     store_keys.append(key_)

# dict_career_MAIN[store_keys[len(store_keys)-7]]
# dict_career[store_keys[len(store_keys)-7]]

# %%
t_ic=time.time()

for YEAR_OF_PGN in range(2014,2017):

    file_to_read = open(path_dicts+"dict_merged_"+str(YEAR_OF_PGN)+".pkl", "rb")
    dict_career= pickle.load(file_to_read)


    it_career=0
    LL=len(dict_career.keys())
    for key_ in dict_career.keys():
        it_career=it_career+1
        career_=dict_career[key_]

        if key_ in dict_career_MAIN.keys():
            dict_career_MAIN[key_]=dict_career_MAIN[key_]+career_
        else:
#             dict_career_MAIN[key_]=career_   
#             issues_=([int(isinstance(elem[0], list)) for elem in career_])
            dict_career_MAIN.setdefault(key_, []).append(career_)

        if it_career % 20000 == 0:
            t_oc = time.time();
            print('YEAR=',YEAR_OF_PGN,'-----',it_career/LL)
            with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_PROG_MERGIN_ALL_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
                file_object.write('Y='+str(YEAR_OF_PGN)+'--'+str(it_career/LL)+'--i.e.-'+str(it_career)+'/'+str(LL)+'----time (s)-'+str(round(t_oc-t_ic,2))+'\n')

# print(t_oc-t_ic)

t_oc=time.time();
print(t_oc-t_ic,' seconds')
# Out:
# YEAR= 2014 ----- 0.10821222581727284
# YEAR= 2014 ----- 0.21642445163454568
# YEAR= 2014 ----- 0.3246366774518185
# YEAR= 2014 ----- 0.43284890326909137
# YEAR= 2014 ----- 0.5410611290863642
# YEAR= 2014 ----- 0.649273354903637
# YEAR= 2014 ----- 0.7574855807209099
# YEAR= 2014 ----- 0.8656978065381827
# YEAR= 2014 ----- 0.9739100323554555

# %%
t_ic=time.time()
LL=len(dict_career_MAIN.keys())
cc=0
for key_ in dict_career_MAIN:
    career_=dict_career_MAIN[key_]
    cc=cc+1;
    if cc % 10000 == 0:
        t_oc = time.time();
        print('done=','-----',cc/LL)
        with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_progress_correcting.txt", "a") as file_object:
            file_object.write(str(cc/LL)+'--i.e.-'+str(cc)+'/'+str(LL)+'----time (s)-'+str(round(t_oc-t_ic,2))+'\n')
    
    len_career=len(career_)
    issues_=([int(isinstance(elem[0], list)) for elem in career_])

   
    if sum(issues_)>0:
        corrected_version=[]
        issues_=np.array(issues_)
        ind1=np.where(issues_==1);ind1=ind1[0]

        for it in range(len_career):
            if it in ind1:
                corrected_version=corrected_version+career_[it]
            else:
                corrected_version=corrected_version+[career_[it]]
                
        dict_career_MAIN[key_]=corrected_version

# %% [markdown]
# #

# %%
# LL=len(dict_career_MAIN.keys())
# file_to_read = open(path_dicts+"dict_full_careers1.pkl", "rb")
# dict_temp= pickle.load(file_to_read)
978868/5000
# Out:
# 19.57736

# %%
t_ic=time.time()
LL=len(dict_career_MAIN.keys())
cc=0
dict_temp={}
count_store=0
for key_ in dict_career_MAIN:
    career_=dict_career_MAIN[key_]
    dict_temp[key_]=career_
    cc=cc+1;
    if (cc % 5000)==0 or (cc==978868) or (cc==978867):
        count_store=count_store+1
        
        file_write=path_dicts+"dict_full_careers"+str(count_store)+".pkl"
#         with open(file_write, 'wb') as f:
#             pickle.dump(dict_temp, f, pickle.HIGHEST_PROTOCOL)
        # creating a pandas dataframe
    
        store_all=[]
        for key_ in dict_temp:
            career_=dict_temp[key_]
            career_=[[key_]+x for x in career_]
            for x in career_:
                store_all.append(x)

        cnames=['player_id','event_type','time_control','white_player','black_player','result_','utcdate',
                    'utctime','whiteelo','blackelo','opening_','actual_game_','termination_']    
        df = pd.DataFrame(store_all)
        df.columns = cnames
        
        # writing to parquet
        names_par=path_dicts+"parquets/dict_full_careers"+str(count_store)+".parquet"
        df.to_parquet(names_par,index=None)
        # emptying the dict to be filled again
        dict_temp={}
        t_oc = time.time();
        print('done=','-----',cc/LL)
        with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_prog_PARQUETS.txt", "a") as file_object:
            file_object.write(str(cc/LL)+'--i.e.-'+str(cc)+'/'+str(LL)+'----time (s)-'+str(round(t_oc-t_ic,2))+'\n')
            
        break

# %% [markdown]
# ## store the dict{name: number of games}

# %% [markdown]
# ## Checking if careers are stored correctly as lists at this step

# %%
cc=0
store_issues=[]
for key_ in dict_career_MAIN:
    cc=cc+1; 
    career_=dict_career_MAIN[key_]
    issues_=([int(isinstance(elem[0], list)) for elem in career_])
    store_issues.append(sum(issues_))

#     if cc>0: 
#         break;
with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_PROG_MERGIN_ALL_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
    file_object.write('number of issues ------------'+str(sum(store_issues))+'\n')

sum(store_issues)

# %%
career_len=[]
cc=0
for key_ in dict_career_MAIN:
    career_len.append(len((dict_career_MAIN[key_])))
#     cc=cc+1; 
#     if cc>10: break;

fig = plt.figure(0,figsize=(6, 3.5));
ax = fig.add_subplot(1, 1, 1);
ax.hist(career_len,1000);

# ax.legend(store_lines,leg_,loc=(1.04,0));
ax.set(xlabel="career length (# games), L ", ylabel='P(L)');
ax.set_yscale('log',base=10)

# ax.set_xticks(xtick_s)
# ax.set_xlim(1,100);

# %%
career_len=np.array(career_len)
ind=np.where(career_len>1000)
print(len(ind[0]),len(career_len))
# Out:
# 56130 978868

# %%
cc=0;
for key_ in dict_career.keys():
    print(key_); cc=cc+1
    if cc>5:    break

# %%
dict_career['claudiomat']

# %%
# with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_PROG_MERGIN_ALL_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
#     file_object.write('writing dict to file ------------\n')
# t_ic=time.time()    
# # f = open(file_write,"w")
# # f.write( str(dict_career_MAIN) )
# # f.close()


# file_write=path_dicts+"dict_CHESS_CAREERS_ALL_YEARS"+".txt"


# with open(file_write, 'w') as f: 
#     for key, value in dict_career_MAIN.items(): 
#         f.write('%s:%s\n' % (key, value))


# t_oc=time.time() 
# with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_PROG_MERGIN_ALL_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
#     file_object.write('done writing dict to file ------------Time taken='+str(t_oc-t_oc)'\n')

# %%
#----------------------------------------------------
# Writing dictionary to file 
#----------------------------------------------------       
# with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_PROG_MERGIN_ALL_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
#     file_object.write('writing dict to file ------------\n')

# file_write=path_dicts+"dict_CHESS_CAREERS_ALL_YEARS"+".pkl"
# with open(file_write, 'wb') as f:
#     pickle.dump(dict_career_MAIN, f, pickle.HIGHEST_PROTOCOL)
    
# with open("/mnt/sdb1/sandeep/0. Careers in chess/0.z_PROG_MERGIN_ALL_"+str(YEAR_OF_PGN)+".txt", "a") as file_object:
#     file_object.write('done writing dict to file ------------\n')
